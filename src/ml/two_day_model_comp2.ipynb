# %% [markdown]
# # Two Day Model for Component 2

# %% [markdown]
# ## Data Prep

# %% [markdown]
# ### Loading and Building Signal

# %%
# %cd ../..
from src.data.files import Data
from src.data.synthesizer import MachineSignalSynth, OneHotColumn, JoinColumns, ConvolveBoleanColumns

import pandas as pd
from sklearn.model_selection import train_test_split

COMPONENT = "comp2"
JOIN_COLS = ["error" + str(i) for i in range(1,6)]
JOIN_COLS.extend(["maint_comp" + str(i) for i in range(1,5)])
JOIN_COLS.append("failure_" + COMPONENT)

LABEL = "failure_" + COMPONENT
all_events = Data.get_events()
tel = Data.get_telemetry()
synthesizer_methods = [JoinColumns(JOIN_COLS),
                       OneHotColumn("model"),
                       ConvolveBoleanColumns(cols=JOIN_COLS,
                                             in_place=[False]*(len(JOIN_COLS) - 1) + [True],
                                             label=LABEL,
                                             delta_ts=[48]*len(JOIN_COLS))]
synthesizer = MachineSignalSynth(tel, all_events, synthesizer_methods)
raw_signal = synthesizer.generate()
# Out:
# /Users/legross/Code/marching-penguin

# %%
ANOMALY = "anomaly"
MODEL = "model"

raw_signal[ANOMALY] = raw_signal[ANOMALY].astype(int)

# %% [markdown]
# ### Signal Description/Verification

# %% [markdown]
# #### Failure Signal

# %% [markdown]
# From the all_events data, let's take a look at the first two failures,

# %%
all_events.loc[all_events.failure_comp2 == True].head(2)
# Out:
#                 datetime  machineID  failure_comp1  failure_comp2  \
# 2616 2015-04-20 06:00:00          1              0              1
# 6936 2015-10-17 06:00:00          1              0              1
#
#       failure_comp3  failure_comp4  maint_comp1  maint_comp2  maint_comp3  \
# 2616              0              0            0            1            0
# 6936              0              0            0            1            0
#
#       maint_comp4  error1  error2  error3  error4  error5  failure  maint  \
# 2616            0       0       0       0       0       0     True   True
# 6936            1       0       0       0       0       0     True   True
#
#       error  anomaly
# 2616  False     True
# 6936  False     True

# %% [markdown]
# The first failure occurs at time stamp "2015-04-20 06:00:00." Our label "failure_comp2" is in the 18th column of the signal. At that time step we expect the label to be 1.0 or True for machineID 1,

# %%
raw_signal.loc[(raw_signal.datetime == "2015-04-20 06:00:00") & (raw_signal.machineID == 1)].iloc[:, :18]
# Out:
#                 datetime  machineID        volt     rotate    pressure  \
# 2616 2015-04-20 06:00:00          1  180.050801  346.36248  105.661164
#
#       vibration  age  anomaly  error1  error2  error3  error4  error5  \
# 2616  39.218055   18        1       0       0       0       0       0
#
#       maint_comp1  maint_comp2  maint_comp3  maint_comp4  failure_comp2
# 2616            0            1            0            0            1.0

# %% [markdown]
# The convolution filter for the **label** tells us if the label will be true in the **next** 48 hours (since that is what we are trying to predict).

# %%
machine_1_signal = raw_signal.loc[raw_signal.machineID == 1]
mask = (machine_1_signal['datetime'] > "2015-04-19 03:00:00") & (machine_1_signal['datetime'] <= "2015-04-20 09:00:00")
machine_1_signal[mask][["datetime", LABEL]]
# Out:
#                 datetime  failure_comp2
# 2590 2015-04-19 04:00:00            1.0
# 2591 2015-04-19 05:00:00            1.0
# 2592 2015-04-19 06:00:00            1.0
# 2593 2015-04-19 07:00:00            1.0
# 2594 2015-04-19 08:00:00            1.0
# 2595 2015-04-19 09:00:00            1.0
# 2596 2015-04-19 10:00:00            1.0
# 2597 2015-04-19 11:00:00            1.0
# 2598 2015-04-19 12:00:00            1.0
# 2599 2015-04-19 13:00:00            1.0
# 2600 2015-04-19 14:00:00            1.0
# 2601 2015-04-19 15:00:00            1.0
# 2602 2015-04-19 16:00:00            1.0
# 2603 2015-04-19 17:00:00            1.0
# 2604 2015-04-19 18:00:00            1.0
# 2605 2015-04-19 19:00:00            1.0
# 2606 2015-04-19 20:00:00            1.0
# 2607 2015-04-19 21:00:00            1.0
# 2608 2015-04-19 22:00:00            1.0
# 2609 2015-04-19 23:00:00            1.0
# 2610 2015-04-20 00:00:00            1.0
# 2611 2015-04-20 01:00:00            1.0
# 2612 2015-04-20 02:00:00            1.0
# 2613 2015-04-20 03:00:00            1.0
# 2614 2015-04-20 04:00:00            1.0
# 2615 2015-04-20 05:00:00            1.0
# 2616 2015-04-20 06:00:00            1.0
# 2617 2015-04-20 07:00:00            0.0
# 2618 2015-04-20 08:00:00            0.0
# 2619 2015-04-20 09:00:00            0.0

# %% [markdown]
# #### Error Signal

# %% [markdown]
# Looking at the first two error3 occurences,

# %%
all_events.loc[all_events.error3 == True].head(2)
# Out:
#                 datetime  machineID  failure_comp1  failure_comp2  \
# 62   2015-01-03 20:00:00          1              0              0
# 2592 2015-04-19 06:00:00          1              0              0
#
#       failure_comp3  failure_comp4  maint_comp1  maint_comp2  maint_comp3  \
# 62                0              0            0            0            0
# 2592              0              0            0            0            0
#
#       maint_comp4  error1  error2  error3  error4  error5  failure  maint  \
# 62              0       0       0       1       0       0    False  False
# 2592            0       0       1       1       0       0    False  False
#
#       error  anomaly
# 62     True     True
# 2592   True     True

# %% [markdown]
# The first error3 occurs at time stamp "2015-01-03 20:00:00."

# %%
raw_signal.loc[(raw_signal.datetime == "2015-01-03 20:00:00") & (raw_signal.machineID == 1)].iloc[:, :18]
# Out:
#               datetime  machineID        volt      rotate   pressure  \
# 62 2015-01-03 20:00:00          1  163.783704  520.582694  97.160984
#
#     vibration  age  anomaly  error1  error2  error3  error4  error5  \
# 62  56.442488   18        1       0       0       1       0       0
#
#     maint_comp1  maint_comp2  maint_comp3  maint_comp4  failure_comp2
# 62            0            0            0            0            0.0

# %% [markdown]
# The convolution filter for **features** tells us if something happened in the **past** 48 hours.

# %%
machine_1_signal = raw_signal.loc[raw_signal.machineID == 1]
mask = (machine_1_signal['datetime'] > "2015-01-03 18:00:00") & (machine_1_signal['datetime'] <= "2015-01-04 23:00:00")
machine_1_signal[mask][["datetime", "error3_in_past_48"]]
# Out:
#               datetime  error3_in_past_48
# 61 2015-01-03 19:00:00                0.0
# 62 2015-01-03 20:00:00                1.0
# 63 2015-01-03 21:00:00                1.0
# 64 2015-01-03 22:00:00                1.0
# 65 2015-01-03 23:00:00                1.0
# 66 2015-01-04 00:00:00                1.0
# 67 2015-01-04 01:00:00                1.0
# 68 2015-01-04 02:00:00                1.0
# 69 2015-01-04 03:00:00                1.0
# 70 2015-01-04 04:00:00                1.0
# 71 2015-01-04 05:00:00                1.0
# 72 2015-01-04 06:00:00                1.0
# 73 2015-01-04 07:00:00                1.0
# 74 2015-01-04 08:00:00                1.0
# 75 2015-01-04 09:00:00                1.0
# 76 2015-01-04 10:00:00                1.0
# 77 2015-01-04 11:00:00                1.0
# 78 2015-01-04 12:00:00                1.0
# 79 2015-01-04 13:00:00                1.0
# 80 2015-01-04 14:00:00                1.0
# 81 2015-01-04 15:00:00                1.0
# 82 2015-01-04 16:00:00                1.0
# 83 2015-01-04 17:00:00                1.0
# 84 2015-01-04 18:00:00                1.0
# 85 2015-01-04 19:00:00                1.0
# 86 2015-01-04 20:00:00                1.0
# 87 2015-01-04 21:00:00                1.0
# 88 2015-01-04 22:00:00                1.0
# 89 2015-01-04 23:00:00                1.0

# %% [markdown]
# #### General Raw Signal

# %%
raw_signal.head()
# Out:
#                   datetime  machineID        volt      rotate    pressure  \
# 0      2015-01-01 06:00:00          1  176.217853  418.504078  113.077935
# 455572 2015-01-01 06:00:00         53  183.084582  420.980061  109.235805
# 858578 2015-01-01 06:00:00         99  168.596133  384.747105  110.921131
# 96371  2015-01-01 06:00:00         12  171.404215  576.923563   97.145400
# 43805  2015-01-01 06:00:00          6  136.878588  492.088420  149.003582
#
#         vibration  age  anomaly  error1  error2  ...  model4  \
# 0       45.087686   18        0       0       0  ...       0
# 455572  45.737760    5        0       0       0  ...       0
# 858578  41.944692   14        0       0       0  ...       0
# 96371   47.725909    9        0       0       0  ...       0
# 43805   22.973289    7        0       0       0  ...       0
#
#         error1_in_past_48  error2_in_past_48  error3_in_past_48  \
# 0                     0.0                0.0                0.0
# 455572                0.0                0.0                0.0
# 858578                0.0                0.0                0.0
# 96371                 0.0                0.0                0.0
# 43805                 0.0                0.0                0.0
#
#         error4_in_past_48  error5_in_past_48  maint_comp1_in_past_48  \
# 0                     0.0                0.0                     0.0
# 455572                0.0                0.0                     0.0
# 858578                0.0                0.0                     0.0
# 96371                 0.0                0.0                     0.0
# 43805                 0.0                0.0                     0.0
#
#         maint_comp2_in_past_48  maint_comp3_in_past_48  maint_comp4_in_past_48
# 0                          0.0                     0.0                     0.0
# 455572                     0.0                     0.0                     0.0
# 858578                     0.0                     0.0                     0.0
# 96371                      0.0                     0.0                     0.0
# 43805                      0.0                     0.0                     0.0
#
# [5 rows x 31 columns]

# %%
print(f"Failure vs normal labels: {len(raw_signal.loc[raw_signal[LABEL] == True].index) / len(raw_signal.index) * 100} %")
# Out:
# Failure vs normal labels: 1.4101130007989955 %

# %% [markdown]
# ## Train/Val/Test Splitting

# %%
y = raw_signal.loc[:, raw_signal.columns == LABEL]
X = raw_signal.loc[:, raw_signal.columns != LABEL]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, shuffle=False)

# %% [markdown]
# ### Sanity Check

# %% [markdown]
# Training data starts at earlier timestamps.

# %%
X_train.head()
# Out:
#                   datetime  machineID        volt      rotate    pressure  \
# 0      2015-01-01 06:00:00          1  176.217853  418.504078  113.077935
# 455572 2015-01-01 06:00:00         53  183.084582  420.980061  109.235805
# 858578 2015-01-01 06:00:00         99  168.596133  384.747105  110.921131
# 96371  2015-01-01 06:00:00         12  171.404215  576.923563   97.145400
# 43805  2015-01-01 06:00:00          6  136.878588  492.088420  149.003582
#
#         vibration  age  anomaly  error1  error2  ...  model4  \
# 0       45.087686   18        0       0       0  ...       0
# 455572  45.737760    5        0       0       0  ...       0
# 858578  41.944692   14        0       0       0  ...       0
# 96371   47.725909    9        0       0       0  ...       0
# 43805   22.973289    7        0       0       0  ...       0
#
#         error1_in_past_48  error2_in_past_48  error3_in_past_48  \
# 0                     0.0                0.0                0.0
# 455572                0.0                0.0                0.0
# 858578                0.0                0.0                0.0
# 96371                 0.0                0.0                0.0
# 43805                 0.0                0.0                0.0
#
#         error4_in_past_48  error5_in_past_48  maint_comp1_in_past_48  \
# 0                     0.0                0.0                     0.0
# 455572                0.0                0.0                     0.0
# 858578                0.0                0.0                     0.0
# 96371                 0.0                0.0                     0.0
# 43805                 0.0                0.0                     0.0
#
#         maint_comp2_in_past_48  maint_comp3_in_past_48  maint_comp4_in_past_48
# 0                          0.0                     0.0                     0.0
# 455572                     0.0                     0.0                     0.0
# 858578                     0.0                     0.0                     0.0
# 96371                      0.0                     0.0                     0.0
# 43805                      0.0                     0.0                     0.0
#
# [5 rows x 30 columns]

# %% [markdown]
# Validation is later.

# %%
X_val
# Out:
#                   datetime  machineID        volt      rotate    pressure  \
# 250564 2015-08-08 06:00:00         29  171.282232  481.209996  102.743036
# 408262 2015-08-08 06:00:00         47  178.795044  426.146721  105.017558
# 662331 2015-08-08 06:00:00         76  183.061932  449.149734   98.230997
# 574721 2015-08-08 06:00:00         66  164.209160  412.533084   93.624311
# 487111 2015-08-08 06:00:00         56  177.870183  449.365869   94.093720
# ...                    ...        ...         ...         ...         ...
# 366209 2015-10-20 06:00:00         42  158.452457  405.129364  106.064339
# 629039 2015-10-20 06:00:00         72  164.552195  376.148556   93.900139
# 226033 2015-10-20 06:00:00         26  172.369838  455.760415  103.049543
# 681605 2015-10-20 06:00:00         78  179.076624  449.013090   82.255674
# 15769  2015-10-20 06:00:00          2  159.963018  452.864090  104.563861
#
#         vibration  age  anomaly  error1  error2  ...  model4  \
# 250564  39.519892    3        0       0       0  ...       1
# 408262  39.001777    6        0       0       0  ...       0
# 662331  45.061041   10        0       0       0  ...       0
# 574721  41.463793    6        0       0       0  ...       1
# 487111  45.531205   10        0       0       0  ...       0
# ...           ...  ...      ...     ...     ...  ...     ...
# 366209  34.101076    7        0       0       0  ...       0
# 629039  40.664033    2        0       0       0  ...       1
# 226033  38.858137    3        0       0       0  ...       0
# 681605  50.094108   19        0       0       0  ...       1
# 15769   37.485862    7        0       0       0  ...       1
#
#         error1_in_past_48  error2_in_past_48  error3_in_past_48  \
# 250564                0.0                0.0                0.0
# 408262                2.0                0.0                0.0
# 662331                0.0                0.0                0.0
# 574721                0.0                0.0                0.0
# 487111                0.0                0.0                0.0
# ...                   ...                ...                ...
# 366209                1.0                0.0                0.0
# 629039                0.0                0.0                0.0
# 226033                0.0                0.0                0.0
# 681605                0.0                0.0                0.0
# 15769                 0.0                0.0                0.0
#
#         error4_in_past_48  error5_in_past_48  maint_comp1_in_past_48  \
# 250564                0.0                0.0                     0.0
# 408262                0.0                0.0                     1.0
# 662331                0.0                0.0                     0.0
# 574721                1.0                0.0                     0.0
# 487111                0.0                0.0                     0.0
# ...                   ...                ...                     ...
# 366209                0.0                0.0                     0.0
# 629039                0.0                0.0                     1.0
# 226033                0.0                0.0                     0.0
# 681605                0.0                0.0                     0.0
# 15769                 0.0                0.0                     0.0
#
#         maint_comp2_in_past_48  maint_comp3_in_past_48  maint_comp4_in_past_48
# 250564                     0.0                     0.0                     0.0
# 408262                     0.0                     0.0                     0.0
# 662331                     0.0                     0.0                     0.0
# 574721                     0.0                     0.0                     0.0
# 487111                     0.0                     0.0                     0.0
# ...                        ...                     ...                     ...
# 366209                     0.0                     1.0                     0.0
# 629039                     0.0                     1.0                     0.0
# 226033                     1.0                     1.0                     0.0
# 681605                     0.0                     1.0                     0.0
# 15769                      0.0                     0.0                     0.0
#
# [175220 rows x 30 columns]

# %% [markdown]
# ### Formatting for Sagemaker

# %%
train = pd.concat([y_train, X_train], axis=1)
validation = pd.concat([y_val, X_val], axis=1)
test = pd.concat([y_test, X_test], axis=1)

# %%
# Use 'csv' format to store the data
# The first column is expected to be the output column
train.to_csv('train.csv', index=False, header=False)
validation.to_csv('validation.csv', index=False, header=False)
test.to_csv('test.csv', index=False, header=False)

# %% [markdown]
# ### Upload Data for Training, Validation, and Testing

# %%
import sagemaker, boto3, os
bucket = "pmpf-data"
prefix = "sagemaker-xgboost-prediction"

boto3.Session().resource('s3').Bucket(bucket).Object(
    os.path.join(prefix, 'data/train_02_12_16.csv')).upload_file('train.csv')
boto3.Session().resource('s3').Bucket(bucket).Object(
    os.path.join(prefix, 'data/validation_02_12_16.csv')).upload_file('validation.csv')
boto3.Session().resource('s3').Bucket(bucket).Object(
    os.path.join(prefix, 'data/test_02_12_16.csv')).upload_file('test.csv')

# %% [markdown]
# ## Local Model Development/Analysis

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
# from xgboost import XGBClassifier

# %%
model_a = DecisionTreeClassifier(max_depth=3)
# model_a = XGBClassifier()
# Removing dates
model_a.fit(X_train.iloc[:, 1:],y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
y_pred = model_a.predict(X_train.iloc[:, 1:])
print("Train AUC:",metrics.roc_auc_score(y_train, y_pred))
# Out:
# Train AUC: 0.746415004901007

# %%
y_pred = model_a.predict(X_test.iloc[:, 1:])
print("Test AUX:",metrics.roc_auc_score(y_test, y_pred))
# Out:
# Test AUX: 0.7564439931704633

# %%
metrics.confusion_matrix(y_test, y_pred)
# Out:
# array([[172671,    173],
#        [  1155,   1221]])

# %%
list(X_train.columns)
# Out:
# ['datetime',
#  'machineID',
#  'volt',
#  'rotate',
#  'pressure',
#  'vibration',
#  'age',
#  'anomaly',
#  'error1',
#  'error2',
#  'error3',
#  'error4',
#  'error5',
#  'maint_comp1',
#  'maint_comp2',
#  'maint_comp3',
#  'maint_comp4',
#  'model1',
#  'model2',
#  'model3',
#  'model4',
#  'error1_in_past_48',
#  'error2_in_past_48',
#  'error3_in_past_48',
#  'error4_in_past_48',
#  'error5_in_past_48',
#  'maint_comp1_in_past_48',
#  'maint_comp2_in_past_48',
#  'maint_comp3_in_past_48',
#  'maint_comp4_in_past_48']

# %%
from six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus
dot_data = StringIO()
export_graphviz(model_a, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True, feature_names=list(X_train.columns)[1:], class_names=['0','1'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('decision_tree.png')
Image(graph.create_png())

# %% [markdown]
# ## Model Training In Sagemaker

# %%
region = sagemaker.Session().boto_region_name
print("AWS Region: {}".format(region))
role = 'arn:aws:iam::328535504136:role/service-role/AmazonSageMaker-ExecutionRole-20230208T093579'
print("RoleArn: {}".format(role))
# Out:
# AWS Region: us-west-1
# RoleArn: arn:aws:iam::328535504136:role/service-role/AmazonSageMaker-ExecutionRole-20230208T093579

# %%
from sagemaker.debugger import Rule, rule_configs
from sagemaker.session import TrainingInput

s3_output_location='s3://{}/{}/{}'.format(bucket, prefix, 'xgboost_model')

container=sagemaker.image_uris.retrieve("xgboost", region, "1.2-1")
print(container)

xgb_model=sagemaker.estimator.Estimator(
    image_uri=container,
    role=role,
    instance_count=1,
    instance_type='ml.m4.xlarge',
    volume_size=5,
    output_path=s3_output_location,
    sagemaker_session=sagemaker.Session(),
    rules=[Rule.sagemaker(rule_configs.create_xgboost_report())]
)
xgb_model.set_hyperparameters(
    max_depth = 5,
    eta = 0.2,
    gamma = 4,
    min_child_weight = 6,
    subsample = 0.7,
    objective = "binary:logistic",
    num_round = 500
)
# Out:
# 746614075791.dkr.ecr.us-west-1.amazonaws.com/sagemaker-xgboost:1.2-1

# %%
from sagemaker.session import TrainingInput
train_input = TrainingInput(
    "s3://{}/{}/{}".format(bucket, prefix, "data/train_02_12_16.csv"), content_type="csv"
)
validation_input = TrainingInput(
    "s3://{}/{}/{}".format(bucket, prefix, "data/validation_02_12_16.csv"), content_type="csv"
)

# %% [markdown]
# #### TRAIN MODEL

# %%
xgb_model.fit({"train": train_input, "validation": validation_input}, wait=True)
# Out:
# INFO:sagemaker:Creating training-job with name: sagemaker-xgboost-2023-02-13-00-17-11-533
# 2023-02-13 00:17:11 Starting - Starting the training job...
# 2023-02-13 00:17:37 Starting - Preparing the instances for trainingCreateXgboostReport: InProgress
# ......
# 2023-02-13 00:18:35 Downloading - Downloading input data...
# 2023-02-13 00:19:10 Training - Downloading the training image......
# 2023-02-13 00:20:05 Training - Training image download completed. Training in progress..[2023-02-13 00:20:12.397 ip-10-0-155-167.us-west-1.compute.internal:7 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# INFO:sagemaker-containers:Imported framework sagemaker_xgboost_container.training
# INFO:sagemaker-containers:Failed to parse hyperparameter objective value binary:logistic to Json.
# Returning the value itself
# INFO:sagemaker-containers:No GPUs detected (normal if no gpus installed)
# INFO:sagemaker_xgboost_container.training:Running XGBoost Sagemaker in algorithm mode
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Single node training.
# [2023-02-13 00:20:13.573 ip-10-0-155-167.us-west-1.compute.internal:7 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2023-02-13 00:20:13.573 ip-10-0-155-167.us-west-1.compute.internal:7 INFO hook.py:199] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2023-02-13 00:20:13.574 ip-10-0-155-167.us-west-1.compute.internal:7 INFO profiler_config_parser.py:102] User has disabled profiler.
# [2023-02-13 00:20:13.575 ip-10-0-155-167.us-west-1.compute.internal:7 INFO hook.py:253] Saving to /opt/ml/output/tensors
# [2023-02-13 00:20:13.575 ip-10-0-155-167.us-west-1.compute.internal:7 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# INFO:root:Debug hook created from config
# INFO:root:Train matrix has 525660 rows and 30 columns
# INFO:root:Validation matrix has 175220 rows
# [0]#011train-error:0.00771#011validation-error:0.00873
# [2023-02-13 00:20:14.382 ip-10-0-155-167.us-west-1.compute.internal:7 INFO hook.py:413] Monitoring the collections: hyperparameters, feature_importance, metrics, labels, predictions
# [2023-02-13 00:20:14.384 ip-10-0-155-167.us-west-1.compute.internal:7 INFO hook.py:476] Hook is writing from the hook with pid: 7
# [1]#011train-error:0.00765#011validation-error:0.00853
# [2]#011train-error:0.00757#011validation-error:0.00842
# [3]#011train-error:0.00756#011validation-error:0.00845
# [4]#011train-error:0.00754#011validation-error:0.00842
# [5]#011train-error:0.00754#011validation-error:0.00842
# [6]#011train-error:0.00755#011validation-error:0.00840
# [7]#011train-error:0.00753#011validation-error:0.00839
# [8]#011train-error:0.00754#011validation-error:0.00839
# [9]#011train-error:0.00753#011validation-error:0.00839
# [10]#011train-error:0.00753#011validation-error:0.00839
# [11]#011train-error:0.00753#011validation-error:0.00841
# [12]#011train-error:0.00752#011validation-error:0.00842
# [13]#011train-error:0.00752#011validation-error:0.00841
# [14]#011train-error:0.00752#011validation-error:0.00841
# [15]#011train-error:0.00752#011validation-error:0.00842
# [16]#011train-error:0.00752#011validation-error:0.00843
# [17]#011train-error:0.00749#011validation-error:0.00843
# [18]#011train-error:0.00749#011validation-error:0.00842
# [19]#011train-error:0.00747#011validation-error:0.00839
# [20]#011train-error:0.00747#011validation-error:0.00843
# [21]#011train-error:0.00747#011validation-error:0.00843
# [22]#011train-error:0.00747#011validation-error:0.00838
# [23]#011train-error:0.00747#011validation-error:0.00841
# [24]#011train-error:0.00747#011validation-error:0.00841
# [25]#011train-error:0.00746#011validation-error:0.00839
# [26]#011train-error:0.00745#011validation-error:0.00839
# [27]#011train-error:0.00744#011validation-error:0.00836
# [28]#011train-error:0.00745#011validation-error:0.00836
# [29]#011train-error:0.00744#011validation-error:0.00837
# [30]#011train-error:0.00744#011validation-error:0.00838
# [31]#011train-error:0.00744#011validation-error:0.00837
# [32]#011train-error:0.00745#011validation-error:0.00837
# [33]#011train-error:0.00744#011validation-error:0.00837
# [34]#011train-error:0.00743#011validation-error:0.00833
# [35]#011train-error:0.00744#011validation-error:0.00837
# [36]#011train-error:0.00744#011validation-error:0.00835
# [37]#011train-error:0.00743#011validation-error:0.00834
# [38]#011train-error:0.00742#011validation-error:0.00834
# [39]#011train-error:0.00743#011validation-error:0.00834
# [40]#011train-error:0.00742#011validation-error:0.00834
# [41]#011train-error:0.00741#011validation-error:0.00834
# [42]#011train-error:0.00740#011validation-error:0.00834
# [43]#011train-error:0.00740#011validation-error:0.00834
# [44]#011train-error:0.00740#011validation-error:0.00834
# [45]#011train-error:0.00737#011validation-error:0.00835
# [46]#011train-error:0.00737#011validation-error:0.00834
# [47]#011train-error:0.00737#011validation-error:0.00834
# [48]#011train-error:0.00737#011validation-error:0.00835
# [49]#011train-error:0.00736#011validation-error:0.00837
# [50]#011train-error:0.00735#011validation-error:0.00837
# [51]#011train-error:0.00735#011validation-error:0.00837
# [52]#011train-error:0.00735#011validation-error:0.00837
# [53]#011train-error:0.00735#011validation-error:0.00837
# [54]#011train-error:0.00733#011validation-error:0.00838
# [55]#011train-error:0.00731#011validation-error:0.00838
# [56]#011train-error:0.00731#011validation-error:0.00837
# [57]#011train-error:0.00731#011validation-error:0.00837
# [58]#011train-error:0.00731#011validation-error:0.00837
# [59]#011train-error:0.00731#011validation-error:0.00837
# [60]#011train-error:0.00732#011validation-error:0.00835
# [61]#011train-error:0.00731#011validation-error:0.00835
# [62]#011train-error:0.00730#011validation-error:0.00835
# [63]#011train-error:0.00730#011validation-error:0.00838
# [64]#011train-error:0.00729#011validation-error:0.00836
# [65]#011train-error:0.00729#011validation-error:0.00835
# [66]#011train-error:0.00729#011validation-error:0.00835
# [67]#011train-error:0.00729#011validation-error:0.00835
# [68]#011train-error:0.00729#011validation-error:0.00834
# [69]#011train-error:0.00728#011validation-error:0.00834
# [70]#011train-error:0.00726#011validation-error:0.00834
# [71]#011train-error:0.00727#011validation-error:0.00834
# [72]#011train-error:0.00726#011validation-error:0.00837
# [73]#011train-error:0.00726#011validation-error:0.00837
# [74]#011train-error:0.00726#011validation-error:0.00835
# [75]#011train-error:0.00725#011validation-error:0.00837
# [76]#011train-error:0.00725#011validation-error:0.00835
# [77]#011train-error:0.00724#011validation-error:0.00835
# [78]#011train-error:0.00724#011validation-error:0.00835
# [79]#011train-error:0.00724#011validation-error:0.00834
# [80]#011train-error:0.00722#011validation-error:0.00835
# [81]#011train-error:0.00721#011validation-error:0.00835
# [82]#011train-error:0.00720#011validation-error:0.00835
# [83]#011train-error:0.00720#011validation-error:0.00835
# [84]#011train-error:0.00720#011validation-error:0.00837
# [85]#011train-error:0.00720#011validation-error:0.00834
# [86]#011train-error:0.00721#011validation-error:0.00834
# [87]#011train-error:0.00719#011validation-error:0.00836
# [88]#011train-error:0.00719#011validation-error:0.00836
# [89]#011train-error:0.00718#011validation-error:0.00835
# [90]#011train-error:0.00718#011validation-error:0.00835
# [91]#011train-error:0.00719#011validation-error:0.00834
# [92]#011train-error:0.00718#011validation-error:0.00835
# [93]#011train-error:0.00718#011validation-error:0.00835
# [94]#011train-error:0.00717#011validation-error:0.00834
# [95]#011train-error:0.00718#011validation-error:0.00835
# [96]#011train-error:0.00718#011validation-error:0.00835
# [97]#011train-error:0.00717#011validation-error:0.00834
# [98]#011train-error:0.00718#011validation-error:0.00834
# [99]#011train-error:0.00717#011validation-error:0.00834
# [100]#011train-error:0.00717#011validation-error:0.00834
# [101]#011train-error:0.00717#011validation-error:0.00834
# [102]#011train-error:0.00717#011validation-error:0.00833
# [103]#011train-error:0.00716#011validation-error:0.00832
# [104]#011train-error:0.00717#011validation-error:0.00833
# [105]#011train-error:0.00716#011validation-error:0.00833
# [106]#011train-error:0.00716#011validation-error:0.00833
# [107]#011train-error:0.00716#011validation-error:0.00833
# [108]#011train-error:0.00715#011validation-error:0.00832
# [109]#011train-error:0.00716#011validation-error:0.00832
# [110]#011train-error:0.00716#011validation-error:0.00832
# [111]#011train-error:0.00715#011validation-error:0.00835
# [112]#011train-error:0.00715#011validation-error:0.00836
# [113]#011train-error:0.00716#011validation-error:0.00837
# [114]#011train-error:0.00716#011validation-error:0.00838
# [115]#011train-error:0.00716#011validation-error:0.00837
# [116]#011train-error:0.00715#011validation-error:0.00837
# [117]#011train-error:0.00715#011validation-error:0.00837
# [118]#011train-error:0.00715#011validation-error:0.00837
# [119]#011train-error:0.00715#011validation-error:0.00839
# [120]#011train-error:0.00716#011validation-error:0.00838
# [121]#011train-error:0.00715#011validation-error:0.00838
# [122]#011train-error:0.00715#011validation-error:0.00837
# [123]#011train-error:0.00715#011validation-error:0.00837
# [124]#011train-error:0.00714#011validation-error:0.00837
# [125]#011train-error:0.00714#011validation-error:0.00836
# [126]#011train-error:0.00713#011validation-error:0.00837
# [127]#011train-error:0.00713#011validation-error:0.00837
# [128]#011train-error:0.00712#011validation-error:0.00838
# [129]#011train-error:0.00712#011validation-error:0.00838
# [130]#011train-error:0.00711#011validation-error:0.00838
# [131]#011train-error:0.00711#011validation-error:0.00839
# [132]#011train-error:0.00709#011validation-error:0.00838
# [133]#011train-error:0.00708#011validation-error:0.00838
# [134]#011train-error:0.00708#011validation-error:0.00839
# [135]#011train-error:0.00707#011validation-error:0.00839
# [136]#011train-error:0.00708#011validation-error:0.00839
# [137]#011train-error:0.00707#011validation-error:0.00837
# [138]#011train-error:0.00707#011validation-error:0.00837
# [139]#011train-error:0.00707#011validation-error:0.00837
# [140]#011train-error:0.00707#011validation-error:0.00835
# [141]#011train-error:0.00707#011validation-error:0.00836
# [142]#011train-error:0.00707#011validation-error:0.00836
# [143]#011train-error:0.00706#011validation-error:0.00837
# [144]#011train-error:0.00706#011validation-error:0.00837
# [145]#011train-error:0.00706#011validation-error:0.00836
# [146]#011train-error:0.00706#011validation-error:0.00837
# [147]#011train-error:0.00706#011validation-error:0.00837
# [148]#011train-error:0.00706#011validation-error:0.00837
# [149]#011train-error:0.00706#011validation-error:0.00837
# [150]#011train-error:0.00706#011validation-error:0.00837
# [151]#011train-error:0.00706#011validation-error:0.00836
# [152]#011train-error:0.00705#011validation-error:0.00838
# [153]#011train-error:0.00705#011validation-error:0.00838
# [154]#011train-error:0.00704#011validation-error:0.00839
# [155]#011train-error:0.00704#011validation-error:0.00839
# [156]#011train-error:0.00704#011validation-error:0.00841
# [157]#011train-error:0.00704#011validation-error:0.00841
# [158]#011train-error:0.00704#011validation-error:0.00840
# [159]#011train-error:0.00704#011validation-error:0.00841
# [160]#011train-error:0.00702#011validation-error:0.00842
# [161]#011train-error:0.00702#011validation-error:0.00841
# [162]#011train-error:0.00702#011validation-error:0.00843
# [163]#011train-error:0.00702#011validation-error:0.00843
# [164]#011train-error:0.00702#011validation-error:0.00843
# [165]#011train-error:0.00702#011validation-error:0.00844
# [166]#011train-error:0.00702#011validation-error:0.00844
# [167]#011train-error:0.00701#011validation-error:0.00843
# [168]#011train-error:0.00702#011validation-error:0.00843
# [169]#011train-error:0.00702#011validation-error:0.00842
# [170]#011train-error:0.00702#011validation-error:0.00841
# [171]#011train-error:0.00702#011validation-error:0.00841
# [172]#011train-error:0.00701#011validation-error:0.00839
# [173]#011train-error:0.00702#011validation-error:0.00838
# [174]#011train-error:0.00701#011validation-error:0.00839
# [175]#011train-error:0.00700#011validation-error:0.00839
# [176]#011train-error:0.00701#011validation-error:0.00840
# [177]#011train-error:0.00701#011validation-error:0.00840
# [178]#011train-error:0.00700#011validation-error:0.00839
# [179]#011train-error:0.00701#011validation-error:0.00837
# [180]#011train-error:0.00700#011validation-error:0.00837
# [181]#011train-error:0.00700#011validation-error:0.00838
# [182]#011train-error:0.00700#011validation-error:0.00838
# [183]#011train-error:0.00700#011validation-error:0.00838
# [184]#011train-error:0.00701#011validation-error:0.00838
# [185]#011train-error:0.00699#011validation-error:0.00838
# [186]#011train-error:0.00700#011validation-error:0.00838
# [187]#011train-error:0.00700#011validation-error:0.00838
# [188]#011train-error:0.00700#011validation-error:0.00838
# [189]#011train-error:0.00699#011validation-error:0.00839
# [190]#011train-error:0.00699#011validation-error:0.00839
# [191]#011train-error:0.00699#011validation-error:0.00839
# [192]#011train-error:0.00698#011validation-error:0.00839
# [193]#011train-error:0.00699#011validation-error:0.00839
# [194]#011train-error:0.00698#011validation-error:0.00839
# [195]#011train-error:0.00697#011validation-error:0.00839
# [196]#011train-error:0.00698#011validation-error:0.00839
# [197]#011train-error:0.00696#011validation-error:0.00839
# [198]#011train-error:0.00697#011validation-error:0.00839
# [199]#011train-error:0.00697#011validation-error:0.00840
# [200]#011train-error:0.00697#011validation-error:0.00840
# [201]#011train-error:0.00696#011validation-error:0.00840
# [202]#011train-error:0.00696#011validation-error:0.00840
# [203]#011train-error:0.00696#011validation-error:0.00839
# [204]#011train-error:0.00697#011validation-error:0.00840
# [205]#011train-error:0.00697#011validation-error:0.00840
# [206]#011train-error:0.00696#011validation-error:0.00839
# [207]#011train-error:0.00695#011validation-error:0.00839
# [208]#011train-error:0.00695#011validation-error:0.00839
# [209]#011train-error:0.00695#011validation-error:0.00839
# [210]#011train-error:0.00695#011validation-error:0.00839
# [211]#011train-error:0.00694#011validation-error:0.00839
# [212]#011train-error:0.00693#011validation-error:0.00838
# [213]#011train-error:0.00694#011validation-error:0.00839
# [214]#011train-error:0.00694#011validation-error:0.00838
# [215]#011train-error:0.00693#011validation-error:0.00838
# [216]#011train-error:0.00693#011validation-error:0.00836
# [217]#011train-error:0.00694#011validation-error:0.00835
# [218]#011train-error:0.00694#011validation-error:0.00837
# [219]#011train-error:0.00694#011validation-error:0.00835
# [220]#011train-error:0.00694#011validation-error:0.00836
# [221]#011train-error:0.00693#011validation-error:0.00835
# [222]#011train-error:0.00693#011validation-error:0.00836
# [223]#011train-error:0.00693#011validation-error:0.00835
# [224]#011train-error:0.00694#011validation-error:0.00835
# [225]#011train-error:0.00692#011validation-error:0.00837
# [226]#011train-error:0.00692#011validation-error:0.00838
# [227]#011train-error:0.00692#011validation-error:0.00838
# [228]#011train-error:0.00692#011validation-error:0.00837
# [229]#011train-error:0.00690#011validation-error:0.00837
# [230]#011train-error:0.00690#011validation-error:0.00837
# [231]#011train-error:0.00691#011validation-error:0.00838
# [232]#011train-error:0.00689#011validation-error:0.00839
# [233]#011train-error:0.00689#011validation-error:0.00839
# [234]#011train-error:0.00689#011validation-error:0.00840
# [235]#011train-error:0.00688#011validation-error:0.00838
# [236]#011train-error:0.00689#011validation-error:0.00839
# [237]#011train-error:0.00689#011validation-error:0.00839
# [238]#011train-error:0.00689#011validation-error:0.00839
# [239]#011train-error:0.00688#011validation-error:0.00840
# [240]#011train-error:0.00689#011validation-error:0.00839
# [241]#011train-error:0.00688#011validation-error:0.00839
# [242]#011train-error:0.00688#011validation-error:0.00839
# [243]#011train-error:0.00688#011validation-error:0.00839
# [244]#011train-error:0.00689#011validation-error:0.00841
# [245]#011train-error:0.00688#011validation-error:0.00839
# [246]#011train-error:0.00688#011validation-error:0.00839
# [247]#011train-error:0.00688#011validation-error:0.00839
# [248]#011train-error:0.00688#011validation-error:0.00839
# [249]#011train-error:0.00688#011validation-error:0.00839
# [250]#011train-error:0.00688#011validation-error:0.00839
# [251]#011train-error:0.00688#011validation-error:0.00840
# [252]#011train-error:0.00687#011validation-error:0.00841
# [253]#011train-error:0.00687#011validation-error:0.00841
# [254]#011train-error:0.00686#011validation-error:0.00841
# [255]#011train-error:0.00686#011validation-error:0.00841
# [256]#011train-error:0.00687#011validation-error:0.00842
# [257]#011train-error:0.00687#011validation-error:0.00842
# [258]#011train-error:0.00687#011validation-error:0.00842
# [259]#011train-error:0.00687#011validation-error:0.00842
# [260]#011train-error:0.00686#011validation-error:0.00842
# [261]#011train-error:0.00687#011validation-error:0.00844
# [262]#011train-error:0.00687#011validation-error:0.00843
# [263]#011train-error:0.00687#011validation-error:0.00844
# [264]#011train-error:0.00687#011validation-error:0.00845
# [265]#011train-error:0.00687#011validation-error:0.00845
# [266]#011train-error:0.00685#011validation-error:0.00841
# [267]#011train-error:0.00685#011validation-error:0.00840
# [268]#011train-error:0.00685#011validation-error:0.00840
# [269]#011train-error:0.00685#011validation-error:0.00840
# [270]#011train-error:0.00685#011validation-error:0.00840
# [271]#011train-error:0.00685#011validation-error:0.00837
# [272]#011train-error:0.00685#011validation-error:0.00837
# [273]#011train-error:0.00686#011validation-error:0.00835
# [274]#011train-error:0.00685#011validation-error:0.00836
# [275]#011train-error:0.00685#011validation-error:0.00837
# [276]#011train-error:0.00685#011validation-error:0.00837
# [277]#011train-error:0.00685#011validation-error:0.00838
# [278]#011train-error:0.00684#011validation-error:0.00838
# [279]#011train-error:0.00684#011validation-error:0.00838
# [280]#011train-error:0.00683#011validation-error:0.00838
# [281]#011train-error:0.00683#011validation-error:0.00840
# [282]#011train-error:0.00684#011validation-error:0.00841
# [283]#011train-error:0.00684#011validation-error:0.00841
# [284]#011train-error:0.00683#011validation-error:0.00841
# [285]#011train-error:0.00684#011validation-error:0.00842
# [286]#011train-error:0.00684#011validation-error:0.00842
# [287]#011train-error:0.00684#011validation-error:0.00842
# [288]#011train-error:0.00685#011validation-error:0.00842
# [289]#011train-error:0.00684#011validation-error:0.00842
# [290]#011train-error:0.00684#011validation-error:0.00842
# [291]#011train-error:0.00685#011validation-error:0.00842
# [292]#011train-error:0.00684#011validation-error:0.00841
# [293]#011train-error:0.00684#011validation-error:0.00842
# [294]#011train-error:0.00684#011validation-error:0.00843
# [295]#011train-error:0.00683#011validation-error:0.00842
# [296]#011train-error:0.00682#011validation-error:0.00843
# [297]#011train-error:0.00682#011validation-error:0.00843
# [298]#011train-error:0.00683#011validation-error:0.00844
# [299]#011train-error:0.00682#011validation-error:0.00843
# [300]#011train-error:0.00681#011validation-error:0.00842
# [301]#011train-error:0.00681#011validation-error:0.00843
# [302]#011train-error:0.00681#011validation-error:0.00844
# [303]#011train-error:0.00681#011validation-error:0.00845
# [304]#011train-error:0.00681#011validation-error:0.00846
# [305]#011train-error:0.00681#011validation-error:0.00847
# [306]#011train-error:0.00681#011validation-error:0.00843
# [307]#011train-error:0.00681#011validation-error:0.00843
# [308]#011train-error:0.00681#011validation-error:0.00843
# [309]#011train-error:0.00680#011validation-error:0.00843
# [310]#011train-error:0.00679#011validation-error:0.00843
# [311]#011train-error:0.00680#011validation-error:0.00843
# [312]#011train-error:0.00678#011validation-error:0.00841
# [313]#011train-error:0.00678#011validation-error:0.00842
# [314]#011train-error:0.00678#011validation-error:0.00842
# [315]#011train-error:0.00678#011validation-error:0.00842
# [316]#011train-error:0.00678#011validation-error:0.00842
# [317]#011train-error:0.00679#011validation-error:0.00842
# [318]#011train-error:0.00679#011validation-error:0.00841
# [319]#011train-error:0.00679#011validation-error:0.00842
# [320]#011train-error:0.00679#011validation-error:0.00843
# [321]#011train-error:0.00679#011validation-error:0.00842
# [322]#011train-error:0.00679#011validation-error:0.00843
# [323]#011train-error:0.00679#011validation-error:0.00845
# [324]#011train-error:0.00679#011validation-error:0.00845
# [325]#011train-error:0.00679#011validation-error:0.00845
# [326]#011train-error:0.00679#011validation-error:0.00845
# [327]#011train-error:0.00677#011validation-error:0.00844
# [328]#011train-error:0.00677#011validation-error:0.00843
# [329]#011train-error:0.00677#011validation-error:0.00844
# [330]#011train-error:0.00677#011validation-error:0.00844
# [331]#011train-error:0.00676#011validation-error:0.00846
# [332]#011train-error:0.00677#011validation-error:0.00847
# [333]#011train-error:0.00677#011validation-error:0.00847
# [334]#011train-error:0.00677#011validation-error:0.00847
# [335]#011train-error:0.00677#011validation-error:0.00847
# [336]#011train-error:0.00676#011validation-error:0.00847
# [337]#011train-error:0.00677#011validation-error:0.00847
# [338]#011train-error:0.00677#011validation-error:0.00846
# [339]#011train-error:0.00676#011validation-error:0.00846
# [340]#011train-error:0.00677#011validation-error:0.00846
# [341]#011train-error:0.00676#011validation-error:0.00846
# [342]#011train-error:0.00676#011validation-error:0.00845
# [343]#011train-error:0.00675#011validation-error:0.00846
# [344]#011train-error:0.00674#011validation-error:0.00846
# [345]#011train-error:0.00674#011validation-error:0.00846
# [346]#011train-error:0.00674#011validation-error:0.00846
# [347]#011train-error:0.00674#011validation-error:0.00845
# [348]#011train-error:0.00674#011validation-error:0.00843
# [349]#011train-error:0.00674#011validation-error:0.00843
# [350]#011train-error:0.00674#011validation-error:0.00843
# [351]#011train-error:0.00674#011validation-error:0.00841
# [352]#011train-error:0.00674#011validation-error:0.00842
# [353]#011train-error:0.00674#011validation-error:0.00842
# [354]#011train-error:0.00674#011validation-error:0.00842
# [355]#011train-error:0.00674#011validation-error:0.00842
# [356]#011train-error:0.00674#011validation-error:0.00843
# [357]#011train-error:0.00674#011validation-error:0.00843
# [358]#011train-error:0.00674#011validation-error:0.00843
# [359]#011train-error:0.00674#011validation-error:0.00842
# [360]#011train-error:0.00674#011validation-error:0.00842
# [361]#011train-error:0.00674#011validation-error:0.00841
# [362]#011train-error:0.00673#011validation-error:0.00841
# [363]#011train-error:0.00673#011validation-error:0.00843
# [364]#011train-error:0.00673#011validation-error:0.00843
# [365]#011train-error:0.00673#011validation-error:0.00843
# [366]#011train-error:0.00673#011validation-error:0.00843
# [367]#011train-error:0.00672#011validation-error:0.00845
# [368]#011train-error:0.00673#011validation-error:0.00843
# [369]#011train-error:0.00673#011validation-error:0.00844
# [370]#011train-error:0.00673#011validation-error:0.00845
# [371]#011train-error:0.00673#011validation-error:0.00846
# [372]#011train-error:0.00673#011validation-error:0.00847
# [373]#011train-error:0.00672#011validation-error:0.00845
# [374]#011train-error:0.00672#011validation-error:0.00845
# [375]#011train-error:0.00671#011validation-error:0.00846
# [376]#011train-error:0.00671#011validation-error:0.00843
# [377]#011train-error:0.00670#011validation-error:0.00845
# [378]#011train-error:0.00671#011validation-error:0.00843
# [379]#011train-error:0.00671#011validation-error:0.00842
# [380]#011train-error:0.00671#011validation-error:0.00844
# [381]#011train-error:0.00673#011validation-error:0.00845
# [382]#011train-error:0.00673#011validation-error:0.00845
# [383]#011train-error:0.00673#011validation-error:0.00844
# [384]#011train-error:0.00673#011validation-error:0.00844
# [385]#011train-error:0.00672#011validation-error:0.00845
# [386]#011train-error:0.00672#011validation-error:0.00843
# [387]#011train-error:0.00672#011validation-error:0.00843
# [388]#011train-error:0.00671#011validation-error:0.00843
# [389]#011train-error:0.00671#011validation-error:0.00843
# [390]#011train-error:0.00671#011validation-error:0.00845
# [391]#011train-error:0.00671#011validation-error:0.00843
# [392]#011train-error:0.00671#011validation-error:0.00843
# [393]#011train-error:0.00671#011validation-error:0.00843
# [394]#011train-error:0.00672#011validation-error:0.00843
# [395]#011train-error:0.00672#011validation-error:0.00844
# [396]#011train-error:0.00672#011validation-error:0.00844
# [397]#011train-error:0.00672#011validation-error:0.00844
# [398]#011train-error:0.00672#011validation-error:0.00845
# [399]#011train-error:0.00671#011validation-error:0.00846
# [400]#011train-error:0.00671#011validation-error:0.00846
# [401]#011train-error:0.00672#011validation-error:0.00846
# [402]#011train-error:0.00671#011validation-error:0.00846
# [403]#011train-error:0.00671#011validation-error:0.00845
# [404]#011train-error:0.00671#011validation-error:0.00844
# [405]#011train-error:0.00671#011validation-error:0.00845
# [406]#011train-error:0.00671#011validation-error:0.00845
# [407]#011train-error:0.00671#011validation-error:0.00845
# [408]#011train-error:0.00669#011validation-error:0.00847
# [409]#011train-error:0.00670#011validation-error:0.00847
# [410]#011train-error:0.00670#011validation-error:0.00847
# [411]#011train-error:0.00670#011validation-error:0.00848
# [412]#011train-error:0.00670#011validation-error:0.00848
# [413]#011train-error:0.00670#011validation-error:0.00849
# [414]#011train-error:0.00668#011validation-error:0.00848
# [415]#011train-error:0.00668#011validation-error:0.00849
# [416]#011train-error:0.00668#011validation-error:0.00847
# [417]#011train-error:0.00668#011validation-error:0.00846
# [418]#011train-error:0.00668#011validation-error:0.00846
# [419]#011train-error:0.00668#011validation-error:0.00847
# [420]#011train-error:0.00668#011validation-error:0.00846
# [421]#011train-error:0.00668#011validation-error:0.00847
# [422]#011train-error:0.00668#011validation-error:0.00847
# [423]#011train-error:0.00667#011validation-error:0.00847
# [424]#011train-error:0.00667#011validation-error:0.00846
# [425]#011train-error:0.00668#011validation-error:0.00847
# [426]#011train-error:0.00668#011validation-error:0.00846
# [427]#011train-error:0.00667#011validation-error:0.00847
# [428]#011train-error:0.00668#011validation-error:0.00847
# [429]#011train-error:0.00668#011validation-error:0.00846
# [430]#011train-error:0.00668#011validation-error:0.00846
# [431]#011train-error:0.00667#011validation-error:0.00848
# [432]#011train-error:0.00668#011validation-error:0.00848
# [433]#011train-error:0.00668#011validation-error:0.00847
# [434]#011train-error:0.00668#011validation-error:0.00847
# [435]#011train-error:0.00668#011validation-error:0.00846
# [436]#011train-error:0.00669#011validation-error:0.00846
# [437]#011train-error:0.00668#011validation-error:0.00845
# [438]#011train-error:0.00668#011validation-error:0.00845
# [439]#011train-error:0.00668#011validation-error:0.00846
# [440]#011train-error:0.00668#011validation-error:0.00846
# [441]#011train-error:0.00668#011validation-error:0.00845
# [442]#011train-error:0.00668#011validation-error:0.00847
# [443]#011train-error:0.00668#011validation-error:0.00848
# [444]#011train-error:0.00668#011validation-error:0.00847
# [445]#011train-error:0.00668#011validation-error:0.00848
# [446]#011train-error:0.00668#011validation-error:0.00848
# [447]#011train-error:0.00667#011validation-error:0.00847
# [448]#011train-error:0.00667#011validation-error:0.00847
# [449]#011train-error:0.00666#011validation-error:0.00847
# [450]#011train-error:0.00666#011validation-error:0.00847
# [451]#011train-error:0.00666#011validation-error:0.00849
# [452]#011train-error:0.00665#011validation-error:0.00849
# [453]#011train-error:0.00665#011validation-error:0.00849
# [454]#011train-error:0.00664#011validation-error:0.00849
# [455]#011train-error:0.00664#011validation-error:0.00849
# [456]#011train-error:0.00665#011validation-error:0.00849
# [457]#011train-error:0.00664#011validation-error:0.00850
# [458]#011train-error:0.00664#011validation-error:0.00850
# [459]#011train-error:0.00664#011validation-error:0.00850
# [460]#011train-error:0.00664#011validation-error:0.00850
# [461]#011train-error:0.00664#011validation-error:0.00851
# [462]#011train-error:0.00664#011validation-error:0.00850
# [463]#011train-error:0.00664#011validation-error:0.00851
# [464]#011train-error:0.00663#011validation-error:0.00850
# [465]#011train-error:0.00663#011validation-error:0.00849
# [466]#011train-error:0.00663#011validation-error:0.00850
# [467]#011train-error:0.00663#011validation-error:0.00850
# [468]#011train-error:0.00663#011validation-error:0.00850
# [469]#011train-error:0.00663#011validation-error:0.00850
# [470]#011train-error:0.00663#011validation-error:0.00849
# [471]#011train-error:0.00663#011validation-error:0.00849
# [472]#011train-error:0.00663#011validation-error:0.00850
# [473]#011train-error:0.00663#011validation-error:0.00851
# [474]#011train-error:0.00663#011validation-error:0.00851
# [475]#011train-error:0.00662#011validation-error:0.00850
# [476]#011train-error:0.00662#011validation-error:0.00851
# [477]#011train-error:0.00662#011validation-error:0.00850
# [478]#011train-error:0.00662#011validation-error:0.00851
# [479]#011train-error:0.00661#011validation-error:0.00850
# [480]#011train-error:0.00660#011validation-error:0.00850
# [481]#011train-error:0.00661#011validation-error:0.00849
# [482]#011train-error:0.00661#011validation-error:0.00849
# [483]#011train-error:0.00662#011validation-error:0.00850
# [484]#011train-error:0.00661#011validation-error:0.00851
# [485]#011train-error:0.00660#011validation-error:0.00852
# [486]#011train-error:0.00660#011validation-error:0.00851
# [487]#011train-error:0.00660#011validation-error:0.00852
# [488]#011train-error:0.00661#011validation-error:0.00852
# [489]#011train-error:0.00660#011validation-error:0.00852
# [490]#011train-error:0.00661#011validation-error:0.00852
# [491]#011train-error:0.00661#011validation-error:0.00853
# [492]#011train-error:0.00661#011validation-error:0.00854
# [493]#011train-error:0.00661#011validation-error:0.00854
# [494]#011train-error:0.00662#011validation-error:0.00854
# [495]#011train-error:0.00662#011validation-error:0.00854
# [496]#011train-error:0.00662#011validation-error:0.00854
# [497]#011train-error:0.00661#011validation-error:0.00853
# [498]#011train-error:0.00661#011validation-error:0.00854
# [499]#011train-error:0.00660#011validation-error:0.00854
#
# 2023-02-13 00:24:52 Uploading - Uploading generated training model
# 2023-02-13 00:24:52 Completed - Training job completed
# Training seconds: 383
# Billable seconds: 383

# %% [markdown]
# #### Deploy Model to Sagemaker

# %%
from sagemaker.serializers import CSVSerializer
xgb_predictor=xgb_model.deploy(
    initial_instance_count=1,
    instance_type='ml.t2.medium',
    serializer=CSVSerializer()
)
# Out:
# INFO:sagemaker:Creating model with name: sagemaker-xgboost-2023-02-13-00-34-37-513
# INFO:sagemaker:Creating endpoint-config with name sagemaker-xgboost-2023-02-13-00-34-37-513
# INFO:sagemaker:Creating endpoint with name sagemaker-xgboost-2023-02-13-00-34-37-513
# --------!

# %%
xgb_predictor.endpoint_name
# Out:
# 'sagemaker-xgboost-2023-02-13-00-34-37-513'

# %% [markdown]
# ## Evaluation

# %% [markdown]
# Getting predictions for the test set from the cloud model.

# %%
import numpy as np
def predict(data, rows=1000):
    split_array = np.array_split(data, int(data.shape[0] / float(rows) + 1))
    predictions = ''
    for array in split_array:
        predictions = ','.join([predictions, xgb_predictor.predict(array).decode('utf-8')])
    return np.fromstring(predictions[1:], sep=',')


inputd = test.to_numpy()[:,1:]
inputd[:, 0] = 0
inputd[:, 6] = 0
inputd[:, 8] = 0
predictions=predict(inputd)

# %% [markdown]
# ### Arbitrary Cutoff

# %% [markdown]
# With an arbitrary cutoff, the confusion matrix is,

# %%
import sklearn

cutoff=0.5
print(sklearn.metrics.confusion_matrix(test.iloc[:, 0], np.where(predictions > cutoff, 1, 0)))
# Out:
# [[172669    175]
#  [  1117   1259]]

# %% [markdown]
# The classification report is as follows, (note especially precision, recall, and f1-score, for postive labels 1.0)

# %%
print(sklearn.metrics.classification_report(test.iloc[:, 0], np.where(predictions > cutoff, 1, 0)))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00    172844
#          1.0       0.88      0.53      0.66      2376
#
#     accuracy                           0.99    175220
#    macro avg       0.94      0.76      0.83    175220
# weighted avg       0.99      0.99      0.99    175220

# %% [markdown]
# ### "Improved" Cutoff

# %% [markdown]
# In predictive maintenance, false negatives tend to be the most costly, so by lowering the cutoff we can reduce the false negatives at the expense of an increased number of false positives.

# %%
cutoff=0.2
print(sklearn.metrics.confusion_matrix(test.iloc[:, 0], np.where(predictions > cutoff, 1, 0)))
# Out:
# [[172371    473]
#  [  1076   1300]]

# %% [markdown]
# Recall increases to 0.55 which means we catch more failures beforehand.

# %%
print(sklearn.metrics.classification_report(test.iloc[:, 0], np.where(predictions > cutoff, 1, 0)))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00    172844
#          1.0       0.73      0.55      0.63      2376
#
#     accuracy                           0.99    175220
#    macro avg       0.86      0.77      0.81    175220
# weighted avg       0.99      0.99      0.99    175220
