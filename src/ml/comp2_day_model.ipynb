# %% [markdown]
# # Component-wise 24 Hr Model

# %% [markdown]
# ## Data Prep

# %% [markdown]
# ### Loading and Building Signal

# %%
# %cd ../..
from src.data.files import Data
from src.data.synthesizer import MachineSignalSynth, OneHotColumn, JoinColumns, ConvolveBoleanColumns

import pandas as pd
from sklearn.model_selection import train_test_split

COMPONENT = "comp2"
JOIN_COLS = ["error" + str(i) for i in range(1,6)]
JOIN_COLS.extend(["maint_comp" + str(i) for i in range(1,5)])
JOIN_COLS.append("failure_" + COMPONENT)

LABEL = "failure_" + COMPONENT
all_events = Data.get_events()
tel = Data.get_telemetry()
synthesizer_methods = [JoinColumns(JOIN_COLS),
                       OneHotColumn("model"),
                       ConvolveBoleanColumns(cols=JOIN_COLS,
                                             in_place=[False]*(len(JOIN_COLS) - 1) + [True],
                                             delta_ts=[24]*len(JOIN_COLS))]
synthesizer = MachineSignalSynth(tel, all_events, synthesizer_methods)
raw_signal = synthesizer.generate()
# Out:
# /Users/legross/Code/marching-penguin

# %%
ANOMALY = "anomaly"
MODEL = "model"

raw_signal[ANOMALY] = raw_signal[ANOMALY].astype(int)

# %% [markdown]
# ### Signal Description/Verification

# %% [markdown]
# From the all_events data, let's take a look at the first two failures,

# %%
all_events.loc[all_events.failure_comp2 == True].head(2)
# Out:
#                 datetime  machineID  failure_comp1  failure_comp2  \
# 2616 2015-04-20 06:00:00          1              0              1
# 6936 2015-10-17 06:00:00          1              0              1
#
#       failure_comp3  failure_comp4  maint_comp1  maint_comp2  maint_comp3  \
# 2616              0              0            0            1            0
# 6936              0              0            0            1            0
#
#       maint_comp4  error1  error2  error3  error4  error5  failure  maint  \
# 2616            0       0       0       0       0       0     True   True
# 6936            1       0       0       0       0       0     True   True
#
#       error  anomaly
# 2616  False     True
# 6936  False     True

# %% [markdown]
# The first failure occurs at time stamp "2015-04-20 06:00:00." Our label "failure_comp2" is in the 18th column of the signal. At that time step we expect the label to be 1.0 or True for machineID 1,

# %%
raw_signal.loc[(raw_signal.datetime == "2015-04-20 06:00:00") & (raw_signal.machineID == 1)].iloc[:, :18]
# Out:
#                 datetime  machineID        volt     rotate    pressure  \
# 2616 2015-04-20 06:00:00          1  180.050801  346.36248  105.661164
#
#       vibration  age  anomaly  error1  error2  error3  error4  error5  \
# 2616  39.218055   18        1       0       0       0       0       0
#
#       maint_comp1  maint_comp2  maint_comp3  maint_comp4  failure_comp2
# 2616            0            1            0            0            1.0

# %% [markdown]
# The convolution filter is such that the labels will be 1.0 for all data points in the past 24 hours, but 0 after the event has occured.

# %%
machine_1_signal = raw_signal.loc[raw_signal.machineID == 1]
mask = (machine_1_signal['datetime'] > "2015-04-19 03:00:00") & (machine_1_signal['datetime'] <= "2015-04-20 09:00:00")
machine_1_signal[mask][["datetime", LABEL]]
# Out:
#                 datetime  failure_comp2
# 2590 2015-04-19 04:00:00            0.0
# 2591 2015-04-19 05:00:00            0.0
# 2592 2015-04-19 06:00:00            0.0
# 2593 2015-04-19 07:00:00            1.0
# 2594 2015-04-19 08:00:00            1.0
# 2595 2015-04-19 09:00:00            1.0
# 2596 2015-04-19 10:00:00            1.0
# 2597 2015-04-19 11:00:00            1.0
# 2598 2015-04-19 12:00:00            1.0
# 2599 2015-04-19 13:00:00            1.0
# 2600 2015-04-19 14:00:00            1.0
# 2601 2015-04-19 15:00:00            1.0
# 2602 2015-04-19 16:00:00            1.0
# 2603 2015-04-19 17:00:00            1.0
# 2604 2015-04-19 18:00:00            1.0
# 2605 2015-04-19 19:00:00            1.0
# 2606 2015-04-19 20:00:00            1.0
# 2607 2015-04-19 21:00:00            1.0
# 2608 2015-04-19 22:00:00            1.0
# 2609 2015-04-19 23:00:00            1.0
# 2610 2015-04-20 00:00:00            1.0
# 2611 2015-04-20 01:00:00            1.0
# 2612 2015-04-20 02:00:00            1.0
# 2613 2015-04-20 03:00:00            1.0
# 2614 2015-04-20 04:00:00            1.0
# 2615 2015-04-20 05:00:00            1.0
# 2616 2015-04-20 06:00:00            1.0
# 2617 2015-04-20 07:00:00            0.0
# 2618 2015-04-20 08:00:00            0.0
# 2619 2015-04-20 09:00:00            0.0

# %%
raw_signal.head()
# Out:
#                   datetime  machineID        volt      rotate    pressure  \
# 0      2015-01-01 06:00:00          1  176.217853  418.504078  113.077935
# 455572 2015-01-01 06:00:00         53  183.084582  420.980061  109.235805
# 858578 2015-01-01 06:00:00         99  168.596133  384.747105  110.921131
# 96371  2015-01-01 06:00:00         12  171.404215  576.923563   97.145400
# 43805  2015-01-01 06:00:00          6  136.878588  492.088420  149.003582
#
#         vibration  age  anomaly  error1  error2  ...  model4  \
# 0       45.087686   18        0       0       0  ...       0
# 455572  45.737760    5        0       0       0  ...       0
# 858578  41.944692   14        0       0       0  ...       0
# 96371   47.725909    9        0       0       0  ...       0
# 43805   22.973289    7        0       0       0  ...       0
#
#         error1_convolve_24  error2_convolve_24  error3_convolve_24  \
# 0                      0.0                 0.0                 0.0
# 455572                 0.0                 0.0                 0.0
# 858578                 0.0                 0.0                 0.0
# 96371                  0.0                 0.0                 0.0
# 43805                  0.0                 0.0                 0.0
#
#         error4_convolve_24  error5_convolve_24  maint_comp1_convolve_24  \
# 0                      0.0                 0.0                      0.0
# 455572                 0.0                 0.0                      0.0
# 858578                 0.0                 0.0                      0.0
# 96371                  0.0                 0.0                      0.0
# 43805                  0.0                 0.0                      0.0
#
#         maint_comp2_convolve_24  maint_comp3_convolve_24  \
# 0                           0.0                      0.0
# 455572                      0.0                      0.0
# 858578                      0.0                      0.0
# 96371                       0.0                      0.0
# 43805                       0.0                      0.0
#
#         maint_comp4_convolve_24
# 0                           0.0
# 455572                      0.0
# 858578                      0.0
# 96371                       0.0
# 43805                       0.0
#
# [5 rows x 31 columns]

# %% [markdown]
# New column label shows whether a machine's compenent will fail in the next 72 hours. Let's look at signal points where the new column is true,

# %%
raw_signal.loc[raw_signal[LABEL] == True]
# Out:
#                   datetime  machineID        volt      rotate    pressure  \
# 499377 2015-01-01 06:00:00         58  196.874272  439.064185   97.176565
# 692119 2015-01-01 06:00:00         80  187.489605  443.209039  101.054717
# 630792 2015-01-01 06:00:00         73  167.639992  376.739783  139.337870
# 692120 2015-01-01 07:00:00         80  151.114448  303.530318   77.519149
# 630793 2015-01-01 07:00:00         73  160.964174  304.508240  134.698681
# ...                    ...        ...         ...         ...         ...
# 17445  2015-12-29 02:00:00          2  154.391321  336.716867   85.480348
# 17446  2015-12-29 03:00:00          2  180.299390  376.813609   99.011382
# 17447  2015-12-29 04:00:00          2  136.025764  275.934792   80.103905
# 17448  2015-12-29 05:00:00          2  174.440209  387.066947   95.294889
# 17449  2015-12-29 06:00:00          2  176.146239  317.711059   94.845424
#
#         vibration  age  anomaly  error1  error2  ...  model4  \
# 499377  39.689021    5        0       0       0  ...       0
# 692119  33.702281    6        0       0       0  ...       0
# 630792  38.120657   20        1       0       0  ...       0
# 692120  29.228292    6        0       0       0  ...       0
# 630793  33.707457   20        0       0       0  ...       0
# ...           ...  ...      ...     ...     ...  ...     ...
# 17445   39.061929    7        0       0       0  ...       1
# 17446   44.147377    7        0       0       0  ...       1
# 17447   41.957460    7        0       0       0  ...       1
# 17448   39.703843    7        0       0       0  ...       1
# 17449   48.679263    7        1       0       0  ...       1
#
#         error1_convolve_24  error2_convolve_24  error3_convolve_24  \
# 499377                 0.0                 0.0                 0.0
# 692119                 0.0                 0.0                 0.0
# 630792                 0.0                 0.0                 0.0
# 692120                 0.0                 0.0                 0.0
# 630793                 0.0                 0.0                 0.0
# ...                    ...                 ...                 ...
# 17445                  0.0                 0.0                 0.0
# 17446                  0.0                 0.0                 0.0
# 17447                  0.0                 0.0                 0.0
# 17448                  0.0                 0.0                 0.0
# 17449                  0.0                 0.0                 0.0
#
#         error4_convolve_24  error5_convolve_24  maint_comp1_convolve_24  \
# 499377                 0.0                 0.0                      0.0
# 692119                 0.0                 0.0                      0.0
# 630792                 1.0                 0.0                      0.0
# 692120                 0.0                 0.0                      0.0
# 630793                 0.0                 0.0                      1.0
# ...                    ...                 ...                      ...
# 17445                  0.0                 0.0                      0.0
# 17446                  0.0                 0.0                      0.0
# 17447                  0.0                 0.0                      0.0
# 17448                  0.0                 0.0                      0.0
# 17449                  0.0                 0.0                      0.0
#
#         maint_comp2_convolve_24  maint_comp3_convolve_24  \
# 499377                      0.0                      0.0
# 692119                      0.0                      0.0
# 630792                      0.0                      0.0
# 692120                      0.0                      0.0
# 630793                      0.0                      1.0
# ...                         ...                      ...
# 17445                       1.0                      0.0
# 17446                       1.0                      0.0
# 17447                       1.0                      0.0
# 17448                       1.0                      0.0
# 17449                       1.0                      0.0
#
#         maint_comp4_convolve_24
# 499377                      0.0
# 692119                      0.0
# 630792                      0.0
# 692120                      0.0
# 630793                      0.0
# ...                         ...
# 17445                       0.0
# 17446                       0.0
# 17447                       0.0
# 17448                       0.0
# 17449                       0.0
#
# [6210 rows x 31 columns]

# %%
print(f"Failure vs normal labels: {len(raw_signal.loc[raw_signal[LABEL] == True].index) / len(raw_signal.index) * 100} %")
# Out:
# Failure vs normal labels: 0.7088231936993493 %

# %% [markdown]
# ## Train/Val/Test Splitting

# %%
y = raw_signal.loc[:, raw_signal.columns == LABEL]
X = raw_signal.loc[:, raw_signal.columns != LABEL]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, shuffle=False)

# %% [markdown]
# ### Sanity Check

# %% [markdown]
# Training data starts at earlier timestamps.

# %%
X_train.head()
# Out:
#                   datetime  machineID        volt      rotate    pressure  \
# 0      2015-01-01 06:00:00          1  176.217853  418.504078  113.077935
# 455572 2015-01-01 06:00:00         53  183.084582  420.980061  109.235805
# 858578 2015-01-01 06:00:00         99  168.596133  384.747105  110.921131
# 96371  2015-01-01 06:00:00         12  171.404215  576.923563   97.145400
# 43805  2015-01-01 06:00:00          6  136.878588  492.088420  149.003582
#
#         vibration  age  anomaly  error1  error2  ...  model4  \
# 0       45.087686   18        0       0       0  ...       0
# 455572  45.737760    5        0       0       0  ...       0
# 858578  41.944692   14        0       0       0  ...       0
# 96371   47.725909    9        0       0       0  ...       0
# 43805   22.973289    7        0       0       0  ...       0
#
#         error1_convolve_24  error2_convolve_24  error3_convolve_24  \
# 0                      0.0                 0.0                 0.0
# 455572                 0.0                 0.0                 0.0
# 858578                 0.0                 0.0                 0.0
# 96371                  0.0                 0.0                 0.0
# 43805                  0.0                 0.0                 0.0
#
#         error4_convolve_24  error5_convolve_24  maint_comp1_convolve_24  \
# 0                      0.0                 0.0                      0.0
# 455572                 0.0                 0.0                      0.0
# 858578                 0.0                 0.0                      0.0
# 96371                  0.0                 0.0                      0.0
# 43805                  0.0                 0.0                      0.0
#
#         maint_comp2_convolve_24  maint_comp3_convolve_24  \
# 0                           0.0                      0.0
# 455572                      0.0                      0.0
# 858578                      0.0                      0.0
# 96371                       0.0                      0.0
# 43805                       0.0                      0.0
#
#         maint_comp4_convolve_24
# 0                           0.0
# 455572                      0.0
# 858578                      0.0
# 96371                       0.0
# 43805                       0.0
#
# [5 rows x 30 columns]

# %% [markdown]
# Validation is later.

# %%
X_val
# Out:
#                   datetime  machineID        volt      rotate    pressure  \
# 250564 2015-08-08 06:00:00         29  171.282232  481.209996  102.743036
# 408262 2015-08-08 06:00:00         47  178.795044  426.146721  105.017558
# 662331 2015-08-08 06:00:00         76  183.061932  449.149734   98.230997
# 574721 2015-08-08 06:00:00         66  164.209160  412.533084   93.624311
# 487111 2015-08-08 06:00:00         56  177.870183  449.365869   94.093720
# ...                    ...        ...         ...         ...         ...
# 366209 2015-10-20 06:00:00         42  158.452457  405.129364  106.064339
# 629039 2015-10-20 06:00:00         72  164.552195  376.148556   93.900139
# 226033 2015-10-20 06:00:00         26  172.369838  455.760415  103.049543
# 681605 2015-10-20 06:00:00         78  179.076624  449.013090   82.255674
# 15769  2015-10-20 06:00:00          2  159.963018  452.864090  104.563861
#
#         vibration  age  anomaly  error1  error2  ...  model4  \
# 250564  39.519892    3        0       0       0  ...       1
# 408262  39.001777    6        0       0       0  ...       0
# 662331  45.061041   10        0       0       0  ...       0
# 574721  41.463793    6        0       0       0  ...       1
# 487111  45.531205   10        0       0       0  ...       0
# ...           ...  ...      ...     ...     ...  ...     ...
# 366209  34.101076    7        0       0       0  ...       0
# 629039  40.664033    2        0       0       0  ...       1
# 226033  38.858137    3        0       0       0  ...       0
# 681605  50.094108   19        0       0       0  ...       1
# 15769   37.485862    7        0       0       0  ...       1
#
#         error1_convolve_24  error2_convolve_24  error3_convolve_24  \
# 250564                 0.0                 0.0                 0.0
# 408262                 0.0                 0.0                 0.0
# 662331                 0.0                 1.0                 0.0
# 574721                 0.0                 0.0                 0.0
# 487111                 0.0                 0.0                 0.0
# ...                    ...                 ...                 ...
# 366209                 0.0                 0.0                 0.0
# 629039                 0.0                 0.0                 0.0
# 226033                 0.0                 0.0                 0.0
# 681605                 0.0                 0.0                 0.0
# 15769                  0.0                 0.0                 0.0
#
#         error4_convolve_24  error5_convolve_24  maint_comp1_convolve_24  \
# 250564                 0.0                 0.0                      0.0
# 408262                 0.0                 0.0                      0.0
# 662331                 0.0                 0.0                      0.0
# 574721                 0.0                 0.0                      0.0
# 487111                 0.0                 0.0                      0.0
# ...                    ...                 ...                      ...
# 366209                 0.0                 0.0                      0.0
# 629039                 0.0                 0.0                      1.0
# 226033                 0.0                 0.0                      0.0
# 681605                 0.0                 0.0                      0.0
# 15769                  0.0                 0.0                      0.0
#
#         maint_comp2_convolve_24  maint_comp3_convolve_24  \
# 250564                      0.0                      0.0
# 408262                      0.0                      0.0
# 662331                      0.0                      0.0
# 574721                      0.0                      0.0
# 487111                      0.0                      0.0
# ...                         ...                      ...
# 366209                      0.0                      0.0
# 629039                      0.0                      1.0
# 226033                      0.0                      0.0
# 681605                      0.0                      0.0
# 15769                       0.0                      0.0
#
#         maint_comp4_convolve_24
# 250564                      0.0
# 408262                      0.0
# 662331                      0.0
# 574721                      0.0
# 487111                      0.0
# ...                         ...
# 366209                      0.0
# 629039                      0.0
# 226033                      0.0
# 681605                      0.0
# 15769                       0.0
#
# [175220 rows x 30 columns]

# %% [markdown]
# ### Formatting for Sagemaker

# %%
train = pd.concat([y_train, X_train], axis=1)
validation = pd.concat([y_val, X_val], axis=1)
test = pd.concat([y_test, X_test], axis=1)

# %%
# Use 'csv' format to store the data
# The first column is expected to be the output column
train.to_csv('train.csv', index=False, header=False)
validation.to_csv('validation.csv', index=False, header=False)
test.to_csv('test.csv', index=False, header=False)

# %% [markdown]
# ### Upload Data for Training, Validation, and Testing

# %%
import sagemaker, boto3, os
bucket = "pmpf-data"
prefix = "sagemaker-xgboost-prediction"

boto3.Session().resource('s3').Bucket(bucket).Object(
    os.path.join(prefix, 'data/train.csv')).upload_file('train.csv')
boto3.Session().resource('s3').Bucket(bucket).Object(
    os.path.join(prefix, 'data/validation.csv')).upload_file('validation.csv')
boto3.Session().resource('s3').Bucket(bucket).Object(
    os.path.join(prefix, 'data/test.csv')).upload_file('test.csv')

# %% [markdown]
# ## Local Model Development/Analysis

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
# from xgboost import XGBClassifier

# %%
model_a = DecisionTreeClassifier(max_depth=3)
# model_a = XGBClassifier()
# Removing dates
model_a.fit(X_train.iloc[:, 1:],y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
y_pred = model_a.predict(X_train.iloc[:, 1:])
print("Train AUC:",metrics.roc_auc_score(y_train, y_pred))
# Out:
# Train AUC: 0.8467764994345272

# %%
y_pred = model_a.predict(X_test.iloc[:, 1:])
print("Test AUX:",metrics.roc_auc_score(y_test, y_pred))
# Out:
# Test AUX: 0.8453362386664437

# %%
metrics.confusion_matrix(y_test, y_pred)
# Out:
# array([[173624,    372],
#        [   376,    848]])

# %%
list(X_train.columns)
# Out:
# ['datetime',
#  'machineID',
#  'volt',
#  'rotate',
#  'pressure',
#  'vibration',
#  'age',
#  'anomaly',
#  'error1',
#  'error2',
#  'error3',
#  'error4',
#  'error5',
#  'maint_comp1',
#  'maint_comp2',
#  'maint_comp3',
#  'maint_comp4',
#  'model1',
#  'model2',
#  'model3',
#  'model4',
#  'error1_convolve_24',
#  'error2_convolve_24',
#  'error3_convolve_24',
#  'error4_convolve_24',
#  'error5_convolve_24',
#  'maint_comp1_convolve_24',
#  'maint_comp2_convolve_24',
#  'maint_comp3_convolve_24',
#  'maint_comp4_convolve_24']

# %%
from six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus
dot_data = StringIO()
export_graphviz(model_a, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True, feature_names=list(X_train.columns)[1:], class_names=['0','1'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('decision_tree.png')
Image(graph.create_png())

# %% [markdown]
# ## Model Training In Sagemaker

# %%
region = sagemaker.Session().boto_region_name
print("AWS Region: {}".format(region))
role = 'arn:aws:iam::328535504136:role/service-role/AmazonSageMaker-ExecutionRole-20230208T093579'
print("RoleArn: {}".format(role))
# Out:
# AWS Region: us-west-1
# RoleArn: arn:aws:iam::328535504136:role/service-role/AmazonSageMaker-ExecutionRole-20230208T093579

# %%
from sagemaker.debugger import Rule, rule_configs
from sagemaker.session import TrainingInput

s3_output_location='s3://{}/{}/{}'.format(bucket, prefix, 'xgboost_model')

container=sagemaker.image_uris.retrieve("xgboost", region, "1.2-1")
print(container)

xgb_model=sagemaker.estimator.Estimator(
    image_uri=container,
    role=role,
    instance_count=1,
    instance_type='ml.m4.xlarge',
    volume_size=5,
    output_path=s3_output_location,
    sagemaker_session=sagemaker.Session(),
    rules=[Rule.sagemaker(rule_configs.create_xgboost_report())]
)
xgb_model.set_hyperparameters(
    max_depth = 5,
    eta = 0.2,
    gamma = 4,
    min_child_weight = 6,
    subsample = 0.7,
    objective = "binary:logistic",
    num_round = 500
)
# Out:
# 746614075791.dkr.ecr.us-west-1.amazonaws.com/sagemaker-xgboost:1.2-1

# %%
from sagemaker.session import TrainingInput
train_input = TrainingInput(
    "s3://{}/{}/{}".format(bucket, prefix, "data/train.csv"), content_type="csv"
)
validation_input = TrainingInput(
    "s3://{}/{}/{}".format(bucket, prefix, "data/validation.csv"), content_type="csv"
)

# %% [markdown]
# #### TRAIN MODEL

# %%
xgb_model.fit({"train": train_input, "validation": validation_input}, wait=True)
# Out:
# INFO:sagemaker:Creating training-job with name: sagemaker-xgboost-2023-02-11-23-45-01-779
# 2023-02-11 23:45:03 Starting - Starting the training job...
# 2023-02-11 23:45:30 Starting - Preparing the instances for trainingCreateXgboostReport: InProgress
# ......
# 2023-02-11 23:46:24 Downloading - Downloading input data...
# 2023-02-11 23:47:00 Training - Downloading the training image......
# 2023-02-11 23:48:00 Training - Training image download completed. Training in progress..[2023-02-11 23:48:02.740 ip-10-0-119-194.us-west-1.compute.internal:7 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# INFO:sagemaker-containers:Imported framework sagemaker_xgboost_container.training
# INFO:sagemaker-containers:Failed to parse hyperparameter objective value binary:logistic to Json.
# Returning the value itself
# INFO:sagemaker-containers:No GPUs detected (normal if no gpus installed)
# INFO:sagemaker_xgboost_container.training:Running XGBoost Sagemaker in algorithm mode
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Single node training.
# [2023-02-11 23:48:04.005 ip-10-0-119-194.us-west-1.compute.internal:7 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2023-02-11 23:48:04.006 ip-10-0-119-194.us-west-1.compute.internal:7 INFO hook.py:199] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2023-02-11 23:48:04.006 ip-10-0-119-194.us-west-1.compute.internal:7 INFO profiler_config_parser.py:102] User has disabled profiler.
# [2023-02-11 23:48:04.007 ip-10-0-119-194.us-west-1.compute.internal:7 INFO hook.py:253] Saving to /opt/ml/output/tensors
# [2023-02-11 23:48:04.007 ip-10-0-119-194.us-west-1.compute.internal:7 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# INFO:root:Debug hook created from config
# INFO:root:Train matrix has 525660 rows and 30 columns
# INFO:root:Validation matrix has 175220 rows
# [0]#011train-error:0.00426#011validation-error:0.00483
# [2023-02-11 23:48:04.702 ip-10-0-119-194.us-west-1.compute.internal:7 INFO hook.py:413] Monitoring the collections: feature_importance, metrics, labels, predictions, hyperparameters
# [2023-02-11 23:48:04.704 ip-10-0-119-194.us-west-1.compute.internal:7 INFO hook.py:476] Hook is writing from the hook with pid: 7
# [1]#011train-error:0.00423#011validation-error:0.00459
# [2]#011train-error:0.00420#011validation-error:0.00449
# [3]#011train-error:0.00413#011validation-error:0.00445
# [4]#011train-error:0.00411#011validation-error:0.00449
# [5]#011train-error:0.00409#011validation-error:0.00447
# [6]#011train-error:0.00413#011validation-error:0.00446
# [7]#011train-error:0.00413#011validation-error:0.00445
# [8]#011train-error:0.00412#011validation-error:0.00446
# [9]#011train-error:0.00404#011validation-error:0.00444
# [10]#011train-error:0.00402#011validation-error:0.00442
# [11]#011train-error:0.00401#011validation-error:0.00440
# [12]#011train-error:0.00397#011validation-error:0.00436
# [13]#011train-error:0.00393#011validation-error:0.00437
# [14]#011train-error:0.00392#011validation-error:0.00436
# [15]#011train-error:0.00386#011validation-error:0.00438
# [16]#011train-error:0.00382#011validation-error:0.00443
# [17]#011train-error:0.00378#011validation-error:0.00446
# [18]#011train-error:0.00375#011validation-error:0.00445
# [19]#011train-error:0.00374#011validation-error:0.00446
# [20]#011train-error:0.00365#011validation-error:0.00430
# [21]#011train-error:0.00363#011validation-error:0.00429
# [22]#011train-error:0.00362#011validation-error:0.00430
# [23]#011train-error:0.00358#011validation-error:0.00427
# [24]#011train-error:0.00353#011validation-error:0.00429
# [25]#011train-error:0.00352#011validation-error:0.00433
# [26]#011train-error:0.00345#011validation-error:0.00429
# [27]#011train-error:0.00342#011validation-error:0.00428
# [28]#011train-error:0.00341#011validation-error:0.00424
# [29]#011train-error:0.00339#011validation-error:0.00422
# [30]#011train-error:0.00338#011validation-error:0.00421
# [31]#011train-error:0.00335#011validation-error:0.00423
# [32]#011train-error:0.00334#011validation-error:0.00428
# [33]#011train-error:0.00334#011validation-error:0.00432
# [34]#011train-error:0.00331#011validation-error:0.00433
# [35]#011train-error:0.00328#011validation-error:0.00436
# [36]#011train-error:0.00326#011validation-error:0.00437
# [37]#011train-error:0.00326#011validation-error:0.00438
# [38]#011train-error:0.00324#011validation-error:0.00438
# [39]#011train-error:0.00322#011validation-error:0.00440
# [40]#011train-error:0.00317#011validation-error:0.00437
# [41]#011train-error:0.00313#011validation-error:0.00444
# [42]#011train-error:0.00311#011validation-error:0.00451
# [43]#011train-error:0.00310#011validation-error:0.00454
# [44]#011train-error:0.00309#011validation-error:0.00455
# [45]#011train-error:0.00308#011validation-error:0.00456
# [46]#011train-error:0.00304#011validation-error:0.00453
# [47]#011train-error:0.00301#011validation-error:0.00455
# [48]#011train-error:0.00299#011validation-error:0.00457
# [49]#011train-error:0.00296#011validation-error:0.00459
# [50]#011train-error:0.00293#011validation-error:0.00457
# [51]#011train-error:0.00290#011validation-error:0.00454
# [52]#011train-error:0.00290#011validation-error:0.00456
# [53]#011train-error:0.00288#011validation-error:0.00463
# [54]#011train-error:0.00284#011validation-error:0.00462
# [55]#011train-error:0.00283#011validation-error:0.00463
# [56]#011train-error:0.00280#011validation-error:0.00463
# [57]#011train-error:0.00279#011validation-error:0.00465
# [58]#011train-error:0.00278#011validation-error:0.00462
# [59]#011train-error:0.00277#011validation-error:0.00466
# [60]#011train-error:0.00274#011validation-error:0.00471
# [61]#011train-error:0.00273#011validation-error:0.00472
# [62]#011train-error:0.00273#011validation-error:0.00473
# [63]#011train-error:0.00271#011validation-error:0.00473
# [64]#011train-error:0.00269#011validation-error:0.00473
# [65]#011train-error:0.00268#011validation-error:0.00474
# [66]#011train-error:0.00263#011validation-error:0.00473
# [67]#011train-error:0.00264#011validation-error:0.00475
# [68]#011train-error:0.00263#011validation-error:0.00475
# [69]#011train-error:0.00264#011validation-error:0.00480
# [70]#011train-error:0.00262#011validation-error:0.00475
# [71]#011train-error:0.00260#011validation-error:0.00477
# [72]#011train-error:0.00257#011validation-error:0.00475
# [73]#011train-error:0.00254#011validation-error:0.00473
# [74]#011train-error:0.00253#011validation-error:0.00474
# [75]#011train-error:0.00253#011validation-error:0.00474
# [76]#011train-error:0.00253#011validation-error:0.00471
# [77]#011train-error:0.00253#011validation-error:0.00475
# [78]#011train-error:0.00253#011validation-error:0.00474
# [79]#011train-error:0.00251#011validation-error:0.00474
# [80]#011train-error:0.00251#011validation-error:0.00473
# [81]#011train-error:0.00249#011validation-error:0.00470
# [82]#011train-error:0.00250#011validation-error:0.00473
# [83]#011train-error:0.00249#011validation-error:0.00470
# [84]#011train-error:0.00246#011validation-error:0.00475
# [85]#011train-error:0.00243#011validation-error:0.00482
# [86]#011train-error:0.00241#011validation-error:0.00490
# [87]#011train-error:0.00241#011validation-error:0.00490
# [88]#011train-error:0.00241#011validation-error:0.00490
# [89]#011train-error:0.00240#011validation-error:0.00486
# [90]#011train-error:0.00236#011validation-error:0.00487
# [91]#011train-error:0.00236#011validation-error:0.00490
# [92]#011train-error:0.00235#011validation-error:0.00486
# [93]#011train-error:0.00234#011validation-error:0.00487
# [94]#011train-error:0.00233#011validation-error:0.00486
# [95]#011train-error:0.00233#011validation-error:0.00485
# [96]#011train-error:0.00234#011validation-error:0.00486
# [97]#011train-error:0.00234#011validation-error:0.00486
# [98]#011train-error:0.00234#011validation-error:0.00487
# [99]#011train-error:0.00233#011validation-error:0.00487
# [100]#011train-error:0.00232#011validation-error:0.00488
# [101]#011train-error:0.00231#011validation-error:0.00491
# [102]#011train-error:0.00230#011validation-error:0.00490
# [103]#011train-error:0.00225#011validation-error:0.00491
# [104]#011train-error:0.00224#011validation-error:0.00494
# [105]#011train-error:0.00224#011validation-error:0.00495
# [106]#011train-error:0.00221#011validation-error:0.00499
# [107]#011train-error:0.00220#011validation-error:0.00498
# [108]#011train-error:0.00222#011validation-error:0.00503
# [109]#011train-error:0.00222#011validation-error:0.00501
# [110]#011train-error:0.00222#011validation-error:0.00504
# [111]#011train-error:0.00221#011validation-error:0.00502
# [112]#011train-error:0.00219#011validation-error:0.00498
# [113]#011train-error:0.00220#011validation-error:0.00500
# [114]#011train-error:0.00219#011validation-error:0.00500
# [115]#011train-error:0.00219#011validation-error:0.00499
# [116]#011train-error:0.00219#011validation-error:0.00494
# [117]#011train-error:0.00219#011validation-error:0.00496
# [118]#011train-error:0.00219#011validation-error:0.00498
# [119]#011train-error:0.00219#011validation-error:0.00498
# [120]#011train-error:0.00219#011validation-error:0.00498
# [121]#011train-error:0.00218#011validation-error:0.00497
# [122]#011train-error:0.00216#011validation-error:0.00499
# [123]#011train-error:0.00215#011validation-error:0.00499
# [124]#011train-error:0.00213#011validation-error:0.00499
# [125]#011train-error:0.00212#011validation-error:0.00499
# [126]#011train-error:0.00210#011validation-error:0.00500
# [127]#011train-error:0.00209#011validation-error:0.00501
# [128]#011train-error:0.00208#011validation-error:0.00508
# [129]#011train-error:0.00207#011validation-error:0.00510
# [130]#011train-error:0.00206#011validation-error:0.00513
# [131]#011train-error:0.00206#011validation-error:0.00513
# [132]#011train-error:0.00206#011validation-error:0.00513
# [133]#011train-error:0.00204#011validation-error:0.00517
# [134]#011train-error:0.00204#011validation-error:0.00517
# [135]#011train-error:0.00204#011validation-error:0.00517
# [136]#011train-error:0.00202#011validation-error:0.00522
# [137]#011train-error:0.00200#011validation-error:0.00522
# [138]#011train-error:0.00200#011validation-error:0.00520
# [139]#011train-error:0.00200#011validation-error:0.00519
# [140]#011train-error:0.00199#011validation-error:0.00518
# [141]#011train-error:0.00198#011validation-error:0.00521
# [142]#011train-error:0.00198#011validation-error:0.00518
# [143]#011train-error:0.00198#011validation-error:0.00518
# [144]#011train-error:0.00197#011validation-error:0.00518
# [145]#011train-error:0.00197#011validation-error:0.00518
# [146]#011train-error:0.00198#011validation-error:0.00517
# [147]#011train-error:0.00198#011validation-error:0.00518
# [148]#011train-error:0.00198#011validation-error:0.00519
# [149]#011train-error:0.00197#011validation-error:0.00517
# [150]#011train-error:0.00196#011validation-error:0.00518
# [151]#011train-error:0.00197#011validation-error:0.00519
# [152]#011train-error:0.00198#011validation-error:0.00517
# [153]#011train-error:0.00196#011validation-error:0.00517
# [154]#011train-error:0.00196#011validation-error:0.00517
# [155]#011train-error:0.00195#011validation-error:0.00518
# [156]#011train-error:0.00195#011validation-error:0.00518
# [157]#011train-error:0.00196#011validation-error:0.00519
# [158]#011train-error:0.00196#011validation-error:0.00519
# [159]#011train-error:0.00194#011validation-error:0.00520
# [160]#011train-error:0.00194#011validation-error:0.00518
# [161]#011train-error:0.00194#011validation-error:0.00517
# [162]#011train-error:0.00192#011validation-error:0.00517
# [163]#011train-error:0.00191#011validation-error:0.00521
# [164]#011train-error:0.00191#011validation-error:0.00521
# [165]#011train-error:0.00193#011validation-error:0.00523
# [166]#011train-error:0.00193#011validation-error:0.00522
# [167]#011train-error:0.00193#011validation-error:0.00523
# [168]#011train-error:0.00193#011validation-error:0.00523
# [169]#011train-error:0.00192#011validation-error:0.00525
# [170]#011train-error:0.00193#011validation-error:0.00525
# [171]#011train-error:0.00194#011validation-error:0.00522
# [172]#011train-error:0.00192#011validation-error:0.00521
# [173]#011train-error:0.00191#011validation-error:0.00521
# [174]#011train-error:0.00189#011validation-error:0.00519
# [175]#011train-error:0.00190#011validation-error:0.00519
# [176]#011train-error:0.00189#011validation-error:0.00520
# [177]#011train-error:0.00189#011validation-error:0.00521
# [178]#011train-error:0.00188#011validation-error:0.00520
# [179]#011train-error:0.00187#011validation-error:0.00517
# [180]#011train-error:0.00187#011validation-error:0.00518
# [181]#011train-error:0.00188#011validation-error:0.00516
# [182]#011train-error:0.00188#011validation-error:0.00516
# [183]#011train-error:0.00187#011validation-error:0.00516
# [184]#011train-error:0.00187#011validation-error:0.00517
# [185]#011train-error:0.00187#011validation-error:0.00517
# [186]#011train-error:0.00187#011validation-error:0.00521
# [187]#011train-error:0.00186#011validation-error:0.00523
# [188]#011train-error:0.00186#011validation-error:0.00522
# [189]#011train-error:0.00186#011validation-error:0.00522
# [190]#011train-error:0.00185#011validation-error:0.00521
# [191]#011train-error:0.00184#011validation-error:0.00523
# [192]#011train-error:0.00184#011validation-error:0.00523
# [193]#011train-error:0.00184#011validation-error:0.00523
# [194]#011train-error:0.00183#011validation-error:0.00524
# [195]#011train-error:0.00181#011validation-error:0.00526
# [196]#011train-error:0.00183#011validation-error:0.00524
# [197]#011train-error:0.00182#011validation-error:0.00523
# [198]#011train-error:0.00181#011validation-error:0.00524
# [199]#011train-error:0.00182#011validation-error:0.00527
# [200]#011train-error:0.00181#011validation-error:0.00527
# [201]#011train-error:0.00181#011validation-error:0.00526
# [202]#011train-error:0.00180#011validation-error:0.00527
# [203]#011train-error:0.00180#011validation-error:0.00527
# [204]#011train-error:0.00180#011validation-error:0.00527
# [205]#011train-error:0.00180#011validation-error:0.00527
# [206]#011train-error:0.00179#011validation-error:0.00530
# [207]#011train-error:0.00178#011validation-error:0.00530
# [208]#011train-error:0.00178#011validation-error:0.00530
# [209]#011train-error:0.00178#011validation-error:0.00530
# [210]#011train-error:0.00178#011validation-error:0.00530
# [211]#011train-error:0.00178#011validation-error:0.00531
# [212]#011train-error:0.00177#011validation-error:0.00530
# [213]#011train-error:0.00176#011validation-error:0.00525
# [214]#011train-error:0.00176#011validation-error:0.00524
# [215]#011train-error:0.00177#011validation-error:0.00524
# [216]#011train-error:0.00177#011validation-error:0.00525
# [217]#011train-error:0.00178#011validation-error:0.00526
# [218]#011train-error:0.00177#011validation-error:0.00527
# [219]#011train-error:0.00176#011validation-error:0.00526
# [220]#011train-error:0.00175#011validation-error:0.00527
# [221]#011train-error:0.00174#011validation-error:0.00528
# [222]#011train-error:0.00173#011validation-error:0.00529
# [223]#011train-error:0.00173#011validation-error:0.00530
# [224]#011train-error:0.00172#011validation-error:0.00531
# [225]#011train-error:0.00173#011validation-error:0.00528
# [226]#011train-error:0.00173#011validation-error:0.00531
# [227]#011train-error:0.00173#011validation-error:0.00531
# [228]#011train-error:0.00172#011validation-error:0.00529
# [229]#011train-error:0.00172#011validation-error:0.00532
# [230]#011train-error:0.00173#011validation-error:0.00530
# [231]#011train-error:0.00173#011validation-error:0.00531
# [232]#011train-error:0.00173#011validation-error:0.00531
# [233]#011train-error:0.00172#011validation-error:0.00530
# [234]#011train-error:0.00173#011validation-error:0.00530
# [235]#011train-error:0.00173#011validation-error:0.00528
# [236]#011train-error:0.00171#011validation-error:0.00522
# [237]#011train-error:0.00171#011validation-error:0.00523
# [238]#011train-error:0.00169#011validation-error:0.00522
# [239]#011train-error:0.00168#011validation-error:0.00523
# [240]#011train-error:0.00170#011validation-error:0.00521
# [241]#011train-error:0.00172#011validation-error:0.00520
# [242]#011train-error:0.00172#011validation-error:0.00520
# [243]#011train-error:0.00172#011validation-error:0.00522
# [244]#011train-error:0.00171#011validation-error:0.00519
# [245]#011train-error:0.00171#011validation-error:0.00519
# [246]#011train-error:0.00168#011validation-error:0.00519
# [247]#011train-error:0.00170#011validation-error:0.00519
# [248]#011train-error:0.00170#011validation-error:0.00519
# [249]#011train-error:0.00170#011validation-error:0.00519
# [250]#011train-error:0.00170#011validation-error:0.00519
# [251]#011train-error:0.00170#011validation-error:0.00519
# [252]#011train-error:0.00170#011validation-error:0.00519
# [253]#011train-error:0.00170#011validation-error:0.00521
# [254]#011train-error:0.00169#011validation-error:0.00521
# [255]#011train-error:0.00169#011validation-error:0.00521
# [256]#011train-error:0.00169#011validation-error:0.00523
# [257]#011train-error:0.00169#011validation-error:0.00523
# [258]#011train-error:0.00169#011validation-error:0.00523
# [259]#011train-error:0.00170#011validation-error:0.00524
# [260]#011train-error:0.00169#011validation-error:0.00526
# [261]#011train-error:0.00169#011validation-error:0.00525
# [262]#011train-error:0.00169#011validation-error:0.00526
# [263]#011train-error:0.00169#011validation-error:0.00526
# [264]#011train-error:0.00169#011validation-error:0.00527
# [265]#011train-error:0.00169#011validation-error:0.00526
# [266]#011train-error:0.00168#011validation-error:0.00524
# [267]#011train-error:0.00168#011validation-error:0.00528
# [268]#011train-error:0.00167#011validation-error:0.00528
# [269]#011train-error:0.00167#011validation-error:0.00528
# [270]#011train-error:0.00167#011validation-error:0.00526
# [271]#011train-error:0.00168#011validation-error:0.00527
# [272]#011train-error:0.00167#011validation-error:0.00527
# [273]#011train-error:0.00166#011validation-error:0.00526
# [274]#011train-error:0.00166#011validation-error:0.00525
# [275]#011train-error:0.00167#011validation-error:0.00527
# [276]#011train-error:0.00168#011validation-error:0.00528
# [277]#011train-error:0.00168#011validation-error:0.00528
# [278]#011train-error:0.00168#011validation-error:0.00525
# [279]#011train-error:0.00168#011validation-error:0.00526
# [280]#011train-error:0.00168#011validation-error:0.00527
# [281]#011train-error:0.00167#011validation-error:0.00528
# [282]#011train-error:0.00167#011validation-error:0.00527
# [283]#011train-error:0.00167#011validation-error:0.00528
# [284]#011train-error:0.00167#011validation-error:0.00525
# [285]#011train-error:0.00167#011validation-error:0.00526
# [286]#011train-error:0.00167#011validation-error:0.00526
# [287]#011train-error:0.00168#011validation-error:0.00527
# [288]#011train-error:0.00168#011validation-error:0.00527
# [289]#011train-error:0.00168#011validation-error:0.00527
# [290]#011train-error:0.00167#011validation-error:0.00527
# [291]#011train-error:0.00167#011validation-error:0.00525
# [292]#011train-error:0.00167#011validation-error:0.00523
# [293]#011train-error:0.00167#011validation-error:0.00522
# [294]#011train-error:0.00167#011validation-error:0.00522
# [295]#011train-error:0.00167#011validation-error:0.00522
# [296]#011train-error:0.00166#011validation-error:0.00521
# [297]#011train-error:0.00166#011validation-error:0.00522
# [298]#011train-error:0.00166#011validation-error:0.00522
# [299]#011train-error:0.00166#011validation-error:0.00522
# [300]#011train-error:0.00166#011validation-error:0.00522
# [301]#011train-error:0.00166#011validation-error:0.00522
# [302]#011train-error:0.00166#011validation-error:0.00521
# [303]#011train-error:0.00166#011validation-error:0.00520
# [304]#011train-error:0.00166#011validation-error:0.00520
# [305]#011train-error:0.00166#011validation-error:0.00520
# [306]#011train-error:0.00166#011validation-error:0.00521
# [307]#011train-error:0.00165#011validation-error:0.00519
# [308]#011train-error:0.00164#011validation-error:0.00523
# [309]#011train-error:0.00164#011validation-error:0.00523
# [310]#011train-error:0.00163#011validation-error:0.00523
# [311]#011train-error:0.00163#011validation-error:0.00523
# [312]#011train-error:0.00163#011validation-error:0.00522
# [313]#011train-error:0.00161#011validation-error:0.00522
# [314]#011train-error:0.00162#011validation-error:0.00522
# [315]#011train-error:0.00162#011validation-error:0.00524
# [316]#011train-error:0.00162#011validation-error:0.00525
# [317]#011train-error:0.00162#011validation-error:0.00527
# [318]#011train-error:0.00161#011validation-error:0.00526
# [319]#011train-error:0.00161#011validation-error:0.00526
# [320]#011train-error:0.00161#011validation-error:0.00525
# [321]#011train-error:0.00161#011validation-error:0.00525
# [322]#011train-error:0.00161#011validation-error:0.00522
# [323]#011train-error:0.00161#011validation-error:0.00522
# [324]#011train-error:0.00161#011validation-error:0.00522
# [325]#011train-error:0.00161#011validation-error:0.00522
# [326]#011train-error:0.00161#011validation-error:0.00520
# [327]#011train-error:0.00161#011validation-error:0.00523
# [328]#011train-error:0.00161#011validation-error:0.00522
# [329]#011train-error:0.00160#011validation-error:0.00521
# [330]#011train-error:0.00160#011validation-error:0.00521
# [331]#011train-error:0.00160#011validation-error:0.00523
# [332]#011train-error:0.00160#011validation-error:0.00527
# [333]#011train-error:0.00161#011validation-error:0.00524
# [334]#011train-error:0.00160#011validation-error:0.00526
# [335]#011train-error:0.00160#011validation-error:0.00526
# [336]#011train-error:0.00160#011validation-error:0.00526
# [337]#011train-error:0.00161#011validation-error:0.00523
# [338]#011train-error:0.00161#011validation-error:0.00523
# [339]#011train-error:0.00161#011validation-error:0.00523
# [340]#011train-error:0.00161#011validation-error:0.00522
# [341]#011train-error:0.00160#011validation-error:0.00528
# [342]#011train-error:0.00160#011validation-error:0.00527
# [343]#011train-error:0.00159#011validation-error:0.00530
# [344]#011train-error:0.00159#011validation-error:0.00531
# [345]#011train-error:0.00158#011validation-error:0.00529
# [346]#011train-error:0.00159#011validation-error:0.00528
# [347]#011train-error:0.00159#011validation-error:0.00528
# [348]#011train-error:0.00159#011validation-error:0.00528
# [349]#011train-error:0.00159#011validation-error:0.00528
# [350]#011train-error:0.00159#011validation-error:0.00528
# [351]#011train-error:0.00160#011validation-error:0.00528
# [352]#011train-error:0.00160#011validation-error:0.00528
# [353]#011train-error:0.00159#011validation-error:0.00526
# [354]#011train-error:0.00159#011validation-error:0.00527
# [355]#011train-error:0.00158#011validation-error:0.00529
# [356]#011train-error:0.00158#011validation-error:0.00525
# [357]#011train-error:0.00158#011validation-error:0.00525
# [358]#011train-error:0.00157#011validation-error:0.00525
# [359]#011train-error:0.00157#011validation-error:0.00528
# [360]#011train-error:0.00157#011validation-error:0.00528
# [361]#011train-error:0.00157#011validation-error:0.00528
# [362]#011train-error:0.00157#011validation-error:0.00528
# [363]#011train-error:0.00157#011validation-error:0.00528
# [364]#011train-error:0.00155#011validation-error:0.00536
# [365]#011train-error:0.00156#011validation-error:0.00537
# [366]#011train-error:0.00156#011validation-error:0.00536
# [367]#011train-error:0.00156#011validation-error:0.00534
# [368]#011train-error:0.00157#011validation-error:0.00531
# [369]#011train-error:0.00157#011validation-error:0.00532
# [370]#011train-error:0.00155#011validation-error:0.00534
# [371]#011train-error:0.00155#011validation-error:0.00534
# [372]#011train-error:0.00155#011validation-error:0.00532
# [373]#011train-error:0.00155#011validation-error:0.00529
# [374]#011train-error:0.00155#011validation-error:0.00529
# [375]#011train-error:0.00154#011validation-error:0.00529
# [376]#011train-error:0.00154#011validation-error:0.00530
# [377]#011train-error:0.00153#011validation-error:0.00530
# [378]#011train-error:0.00154#011validation-error:0.00531
# [379]#011train-error:0.00153#011validation-error:0.00531
# [380]#011train-error:0.00153#011validation-error:0.00530
# [381]#011train-error:0.00153#011validation-error:0.00532
# [382]#011train-error:0.00153#011validation-error:0.00534
# [383]#011train-error:0.00152#011validation-error:0.00534
# [384]#011train-error:0.00152#011validation-error:0.00533
# [385]#011train-error:0.00153#011validation-error:0.00534
# [386]#011train-error:0.00153#011validation-error:0.00534
# [387]#011train-error:0.00152#011validation-error:0.00534
# [388]#011train-error:0.00152#011validation-error:0.00534
# [389]#011train-error:0.00152#011validation-error:0.00534
# [390]#011train-error:0.00151#011validation-error:0.00536
# [391]#011train-error:0.00150#011validation-error:0.00535
# [392]#011train-error:0.00150#011validation-error:0.00534
# [393]#011train-error:0.00150#011validation-error:0.00534
# [394]#011train-error:0.00151#011validation-error:0.00534
# [395]#011train-error:0.00152#011validation-error:0.00536
# [396]#011train-error:0.00152#011validation-error:0.00535
# [397]#011train-error:0.00152#011validation-error:0.00535
# [398]#011train-error:0.00152#011validation-error:0.00535
# [399]#011train-error:0.00152#011validation-error:0.00534
# [400]#011train-error:0.00151#011validation-error:0.00533
# [401]#011train-error:0.00151#011validation-error:0.00532
# [402]#011train-error:0.00149#011validation-error:0.00534
# [403]#011train-error:0.00150#011validation-error:0.00534
# [404]#011train-error:0.00149#011validation-error:0.00533
# [405]#011train-error:0.00149#011validation-error:0.00534
# [406]#011train-error:0.00150#011validation-error:0.00534
# [407]#011train-error:0.00150#011validation-error:0.00534
# [408]#011train-error:0.00150#011validation-error:0.00534
# [409]#011train-error:0.00150#011validation-error:0.00534
# [410]#011train-error:0.00150#011validation-error:0.00533
# [411]#011train-error:0.00150#011validation-error:0.00534
# [412]#011train-error:0.00150#011validation-error:0.00534
# [413]#011train-error:0.00150#011validation-error:0.00534
# [414]#011train-error:0.00150#011validation-error:0.00532
# [415]#011train-error:0.00150#011validation-error:0.00531
# [416]#011train-error:0.00150#011validation-error:0.00531
# [417]#011train-error:0.00149#011validation-error:0.00530
# [418]#011train-error:0.00149#011validation-error:0.00531
# [419]#011train-error:0.00149#011validation-error:0.00531
# [420]#011train-error:0.00149#011validation-error:0.00531
# [421]#011train-error:0.00149#011validation-error:0.00531
# [422]#011train-error:0.00146#011validation-error:0.00530
# [423]#011train-error:0.00148#011validation-error:0.00530
# [424]#011train-error:0.00148#011validation-error:0.00530
# [425]#011train-error:0.00148#011validation-error:0.00530
# [426]#011train-error:0.00148#011validation-error:0.00530
# [427]#011train-error:0.00147#011validation-error:0.00528
# [428]#011train-error:0.00147#011validation-error:0.00528
# [429]#011train-error:0.00147#011validation-error:0.00528
# [430]#011train-error:0.00147#011validation-error:0.00531
# [431]#011train-error:0.00148#011validation-error:0.00530
# [432]#011train-error:0.00149#011validation-error:0.00528
# [433]#011train-error:0.00149#011validation-error:0.00528
# [434]#011train-error:0.00148#011validation-error:0.00526
# [435]#011train-error:0.00147#011validation-error:0.00528
# [436]#011train-error:0.00147#011validation-error:0.00528
# [437]#011train-error:0.00147#011validation-error:0.00528
# [438]#011train-error:0.00147#011validation-error:0.00528
# [439]#011train-error:0.00148#011validation-error:0.00531
# [440]#011train-error:0.00147#011validation-error:0.00532
# [441]#011train-error:0.00147#011validation-error:0.00533
# [442]#011train-error:0.00147#011validation-error:0.00534
# [443]#011train-error:0.00146#011validation-error:0.00533
# [444]#011train-error:0.00147#011validation-error:0.00533
# [445]#011train-error:0.00146#011validation-error:0.00534
# [446]#011train-error:0.00147#011validation-error:0.00531
# [447]#011train-error:0.00148#011validation-error:0.00531
# [448]#011train-error:0.00148#011validation-error:0.00532
# [449]#011train-error:0.00147#011validation-error:0.00533
# [450]#011train-error:0.00146#011validation-error:0.00531
# [451]#011train-error:0.00148#011validation-error:0.00534
# [452]#011train-error:0.00148#011validation-error:0.00534
# [453]#011train-error:0.00148#011validation-error:0.00534
# [454]#011train-error:0.00148#011validation-error:0.00532
# [455]#011train-error:0.00148#011validation-error:0.00532
# [456]#011train-error:0.00148#011validation-error:0.00532
# [457]#011train-error:0.00148#011validation-error:0.00531
# [458]#011train-error:0.00149#011validation-error:0.00528
# [459]#011train-error:0.00148#011validation-error:0.00528
# [460]#011train-error:0.00148#011validation-error:0.00527
# [461]#011train-error:0.00147#011validation-error:0.00528
# [462]#011train-error:0.00147#011validation-error:0.00529
# [463]#011train-error:0.00147#011validation-error:0.00531
# [464]#011train-error:0.00146#011validation-error:0.00531
# [465]#011train-error:0.00145#011validation-error:0.00531
# [466]#011train-error:0.00145#011validation-error:0.00528
# [467]#011train-error:0.00145#011validation-error:0.00528
# [468]#011train-error:0.00145#011validation-error:0.00527
# [469]#011train-error:0.00145#011validation-error:0.00527
# [470]#011train-error:0.00145#011validation-error:0.00528
# [471]#011train-error:0.00145#011validation-error:0.00528
# [472]#011train-error:0.00144#011validation-error:0.00529
# [473]#011train-error:0.00143#011validation-error:0.00531
# [474]#011train-error:0.00143#011validation-error:0.00531
# [475]#011train-error:0.00143#011validation-error:0.00531
# [476]#011train-error:0.00143#011validation-error:0.00531
# [477]#011train-error:0.00143#011validation-error:0.00530
# [478]#011train-error:0.00142#011validation-error:0.00530
# [479]#011train-error:0.00143#011validation-error:0.00531
# [480]#011train-error:0.00143#011validation-error:0.00531
# [481]#011train-error:0.00143#011validation-error:0.00531
# [482]#011train-error:0.00144#011validation-error:0.00530
# [483]#011train-error:0.00143#011validation-error:0.00532
# [484]#011train-error:0.00142#011validation-error:0.00533
# [485]#011train-error:0.00143#011validation-error:0.00532
# [486]#011train-error:0.00143#011validation-error:0.00532
# [487]#011train-error:0.00142#011validation-error:0.00531
# [488]#011train-error:0.00143#011validation-error:0.00531
# [489]#011train-error:0.00143#011validation-error:0.00532
# [490]#011train-error:0.00143#011validation-error:0.00531
# [491]#011train-error:0.00143#011validation-error:0.00534
# [492]#011train-error:0.00144#011validation-error:0.00534
#
# 2023-02-11 23:52:07 Uploading - Uploading generated training model[493]#011train-error:0.00144#011validation-error:0.00534
# [494]#011train-error:0.00143#011validation-error:0.00534
# [495]#011train-error:0.00143#011validation-error:0.00534
# [496]#011train-error:0.00143#011validation-error:0.00533
# [497]#011train-error:0.00143#011validation-error:0.00533
# [498]#011train-error:0.00143#011validation-error:0.00533
# [499]#011train-error:0.00142#011validation-error:0.00534
#
# 2023-02-11 23:52:41 Completed - Training job completed
# Training seconds: 359
# Billable seconds: 359

# %% [markdown]
# #### Deploy Model to Sagemaker

# %%
from sagemaker.serializers import CSVSerializer
xgb_predictor=xgb_model.deploy(
    initial_instance_count=1,
    instance_type='ml.t2.medium',
    serializer=CSVSerializer()
)
# Out:
# INFO:sagemaker:Creating model with name: sagemaker-xgboost-2023-02-12-00-09-14-542
# INFO:sagemaker:Creating endpoint-config with name sagemaker-xgboost-2023-02-12-00-09-14-542
# INFO:sagemaker:Creating endpoint with name sagemaker-xgboost-2023-02-12-00-09-14-542
# -------!

# %%
xgb_predictor.endpoint_name
# Out:
# 'sagemaker-xgboost-2023-02-12-00-09-14-542'

# %% [markdown]
# ## Evaluation

# %% [markdown]
# Getting predictions for the test set from the cloud model.

# %%
import numpy as np
def predict(data, rows=1000):
    split_array = np.array_split(data, int(data.shape[0] / float(rows) + 1))
    predictions = ''
    for array in split_array:
        predictions = ','.join([predictions, xgb_predictor.predict(array).decode('utf-8')])
    return np.fromstring(predictions[1:], sep=',')

# %% [markdown]
# ### Arbitrary Cutoff

# %% [markdown]
# With an arbitrary cutoff, the confusion matrix is,

# %%
import sklearn

cutoff=0.5
print(sklearn.metrics.confusion_matrix(test.iloc[:, 0], np.where(predictions > cutoff, 1, 0)))
# Out:
# [[173614    382]
#  [   536    688]]

# %% [markdown]
# The classification report is as follows, (note especially precision, recall, and f1-score, for postive labels 1.0)

# %%
print(sklearn.metrics.classification_report(test.iloc[:, 0], np.where(predictions > cutoff, 1, 0)))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00    173996
#          1.0       0.64      0.56      0.60      1224
#
#     accuracy                           0.99    175220
#    macro avg       0.82      0.78      0.80    175220
# weighted avg       0.99      0.99      0.99    175220

# %% [markdown]
# ### "Improved" Cutoff

# %% [markdown]
# In predictive maintenance, false negatives tend to be the most costly, so by lowering the cutoff we can reduce the false negatives at the expense of an increased number of false positives.

# %%
cutoff=0.2
print(sklearn.metrics.confusion_matrix(test.iloc[:, 0], np.where(predictions > cutoff, 1, 0)))
# Out:
# [[173216    780]
#  [   282    942]]

# %% [markdown]
# Recall increases to 0.77 which means we catch more failures beforehand.

# %%
print(sklearn.metrics.classification_report(test.iloc[:, 0], np.where(predictions > cutoff, 1, 0)))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00    173996
#          1.0       0.55      0.77      0.64      1224
#
#     accuracy                           0.99    175220
#    macro avg       0.77      0.88      0.82    175220
# weighted avg       1.00      0.99      0.99    175220
